# %% [markdown]
# <a href="https://colab.research.google.com/github/kwalker7631/stable-diffusion-webui-colab/blob/main/SvengAlI_SAI_Global_Nightly_webui_colab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Mounts your Google Drive to Runtime.

# %%
#@title
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
#@title Installs Google Drive.  { vertical-output: true }
# Import PyDrive and associated libraries.
# This only needs to be done once per notebook.
from pydrive.auth import GoogleAuth
from pydrive.drive import GoogleDrive
from google.colab import auth
from oauth2client.client import GoogleCredentials

# Authenticate and create the PyDrive client.
# This only needs to be done once per notebook.
auth.authenticate_user()
gauth = GoogleAuth()
gauth.credentials = GoogleCredentials.get_application_default()
drive = GoogleDrive(gauth)

# List .txt files in the root.
#
# Search query reference:
# https://developers.google.com/drive/v2/web/search-parameters
listed = drive.ListFile({'q': "title contains '.txt' and 'root' in parents"}).GetList()
for file in listed:
  print('title {}, id {}'.format(file['title'], file['id']))
# Out:
# title foo.txt, id 1tI_ymasNzxOlPpqCifOAKb5ZRAjCQqsN

# %%
################
##### FORM #####
################

#@title #Customize your settings then run the cell
#@markdown #####*(<- Press the "play" button to run. Default settings are good for beginners, just select a model and run. You can find most of the models on <a href="https://civitai.com">CivitAI</a>. Don't run this cell twice, if you need to re-run, use the next cell labeled "<a href="#scrollTo=dTagfxeRig0n">Reconnect</a>")*
#@markdown ___
#@markdown ##*Choose a model*
#@markdown <details><summary>Click here to show/hide models' specificities</summary><table><thead><tr><th>Model</th><th>All in One Pixel Model</th><th>Analog Diffusion</th><th>Arcane Diffusion 3</th><th>Cinematic Diffusion</th><th>Comic Diffusion</th><th>Comics Blend</th><th>Complex Lineart</th><th>Cyberpunk Anime Diffusion</th><th>Dreamlike Diffusion</th><th>Food Crit</th><th>Illuminati v1.1</th><th>Illustration Diffusion</th><th>Inkpunk</th><th>Knollingcase</th><th>Midjourney v4</th><th>Mo Di Diffusion</th><th>Papercut</th><th>Popup Book</th><th>Riffusion</th><th>Rmada Merge v5</th><th>Rmadart v5</th><th>SamDoesArt</th><th>Stable Diffusion 2 Depth</th><th>Stable Diffusion 2.1</th><th>Synthwave punk v2</th><th>Van Gogh Diffusion</th><th>Vintedois Diffusion</th><th>Woolitize</th></tr></thead><tbody><tr><td>Special notes</td><td>Positive prompt:<br>    pixelsprite<br>    16bitscene</td><td>Positive prompt:<br>    analog style</td><td>Positive prompt:<br>    arcane style</td><td>Positive prompt:<br>    syberart</td><td>Positive prompt:<br>    harliebo artstyle<br>    holliemengert artstyle<br>    marioalberti artstyle<br>    pepelarraz artstyle<br>    andreasrocha artstyle<br>    jamesdaly artstyle</td><td>Positive prompt:<br>    ComplexLA style<br>    nvinkpunk<br>    marioalberti artstyle<br>    ghibli style</td><td>Positive prompt:<br>    ComplexLA style</td><td>Positive prompt:<br>    dgs illustration style</td><td>Positive prompt:<br>    dreamlikeart style</td><td>Positive prompt:<br>    food_crit</td><td>Negative prompt:<br>    nrealfixer<br>    nartfixer<br>    nfixer</td><td>Positive prompt:<br>    holliemengert artstyle</td><td>Positive prompt:<br>    nvinkpunk style</td><td>Positive prompt:<br>    knollingcase</td><td>Positive prompt:<br>    mdjrny-v4 style</td><td>Positive prompt:<br>    modern disney style</td><td>Positive prompt:<br>    PaperCut</td><td>Positive prompt:<br>    popupBook</td><td>Use with the script :<br>    Riffusion Audio Generator</td><td>Negative prompt:<br>&nbsp;&nbsp;&nbsp;&nbsp;nrealfixer<br>&nbsp;&nbsp;&nbsp;&nbsp;nartfixer<br>&nbsp;&nbsp;&nbsp;&nbsp;nfixer</td><td>Negative prompt:<br>&nbsp;&nbsp;&nbsp;&nbsp;nrealfixer<br>&nbsp;&nbsp;&nbsp;&nbsp;nartfixer<br>&nbsp;&nbsp;&nbsp;&nbsp;nfixer</td><td>Positive prompt:<br>    SamDoesArt</td><td>Positive prompt:<br>    FloralMarble-400</td><td>Positive prompt:<br>    dblx<br>    AnimeScreenCap</td><td>Positive prompt:<br>    snthwve style<br>    nvinkpunk</td><td>Positive prompt:<br>    lvngvncnt style</td><td>Positive prompt:<br>    estilovintedois</td><td>Positive prompt:<br>    woolitize style</td></tr></tbody></table></table></details>
#@markdown <details><summary>Click here to show/hide which models download their own VAE, along with comparison grids.</summary><table style="border-collapse:collapse;border-spacing:0" class="tg"><thead><tr><th style="border-color:inherit;border-style:solid;border-width:1px;font-family:Arial, sans-serif;font-size:14px;font-weight:normal;overflow:hidden;padding:10px 5px;text-align:left;vertical-align:top;word-break:normal">VAE</th><th style="border-color:inherit;border-style:solid;border-width:1px;font-family:Arial, sans-serif;font-size:14px;font-weight:normal;overflow:hidden;padding:10px 5px;text-align:left;vertical-align:top;word-break:normal">Models that will automatically download it</th></tr></thead><tbody><tr><td style="border-color:inherit;border-style:solid;border-width:1px;font-family:Arial, sans-serif;font-size:14px;overflow:hidden;padding:10px 5px;text-align:left;vertical-align:top;word-break:normal">Anything v3</td><td style="border-color:inherit;border-style:solid;border-width:1px;font-family:Arial, sans-serif;font-size:14px;overflow:hidden;padding:10px 5px;text-align:left;vertical-align:top;word-break:normal">Abyss Orange Mix 2, Anything v3, Counterfeit 2.5, Monstermash 4/6 + Any v3, Open Anime Journey, Orange Cocoa Mix 2 HARD, Yohan Diffusion</td></tr><tr><td style="border-color:inherit;border-style:solid;border-width:1px;font-family:Arial, sans-serif;font-size:14px;overflow:hidden;padding:10px 5px;text-align:left;vertical-align:top;word-break:normal">Anything v4</td><td style="border-color:inherit;border-style:solid;border-width:1px;font-family:Arial, sans-serif;font-size:14px;overflow:hidden;padding:10px 5px;text-align:left;vertical-align:top;word-break:normal">Anything v4.5, Anything v5</td></tr><tr><td style="border-color:inherit;border-style:solid;border-width:1px;font-family:Arial, sans-serif;font-size:14px;overflow:hidden;padding:10px 5px;text-align:left;vertical-align:top;word-break:normal">Grapefruit</td><td style="border-color:inherit;border-style:solid;border-width:1px;font-family:Arial, sans-serif;font-size:14px;overflow:hidden;padding:10px 5px;text-align:left;vertical-align:top;word-break:normal">Grapefruit, Mistoon Anime</td></tr><tr><td style="border-color:inherit;border-style:solid;border-width:1px;font-family:Arial, sans-serif;font-size:14px;overflow:hidden;padding:10px 5px;text-align:left;vertical-align:top;word-break:normal">kl_f8_anime2</td><td style="border-color:inherit;border-style:solid;border-width:1px;font-family:Arial, sans-serif;font-size:14px;overflow:hidden;padding:10px 5px;text-align:left;vertical-align:top;word-break:normal">AniRealityMix, Color Bomb Mix, Defmix, Dpepmkp, Elysium Anime 2, Face Bomb Mix, Faetastic v1, Fantasy World, Hyper Bomb Mix, Magical Mix 1/2, Pastel Mix (fp16/32), PVC, Waifu Diffusion (all), Yiffy Mix</td></tr><tr><td style="border-color:inherit;border-style:solid;border-width:1px;font-family:Arial, sans-serif;font-size:14px;overflow:hidden;padding:10px 5px;text-align:left;vertical-align:top;word-break:normal">orangemix</td><td style="border-color:inherit;border-style:solid;border-width:1px;font-family:Arial, sans-serif;font-size:14px;overflow:hidden;padding:10px 5px;text-align:left;vertical-align:top;word-break:normal">Abyss Orange Mix 3 (all variants)</td></tr><tr><td style="border-color:inherit;border-style:solid;border-width:1px;font-family:Arial, sans-serif;font-size:14px;overflow:hidden;padding:10px 5px;text-align:left;vertical-align:top;word-break:normal">randomix3</td><td style="border-color:inherit;border-style:solid;border-width:1px;font-family:Arial, sans-serif;font-size:14px;overflow:hidden;padding:10px 5px;text-align:left;vertical-align:top;word-break:normal">Randomix 3</td></tr><tr><td style="border-color:inherit;border-style:solid;border-width:1px;font-family:Arial, sans-serif;font-size:14px;overflow:hidden;padding:10px 5px;text-align:left;vertical-align:top;word-break:normal">refslave</td><td style="border-color:inherit;border-style:solid;border-width:1px;font-family:Arial, sans-serif;font-size:14px;overflow:hidden;padding:10px 5px;text-align:left;vertical-align:top;word-break:normal">RefSlave v2</td></tr><tr><td style="border-color:inherit;border-style:solid;border-width:1px;font-family:Arial, sans-serif;font-size:14px;overflow:hidden;padding:10px 5px;text-align:left;vertical-align:top;word-break:normal">vae-ft-mse-84000-ema-pruned</td><td style="border-color:inherit;border-style:solid;border-width:1px;font-family:Arial, sans-serif;font-size:14px;overflow:hidden;padding:10px 5px;text-align:left;vertical-align:top;word-break:normal">80's Dark Souls Vibe, Alfamix, Amixx, AnyHentai v2, Cardos Animated v2, Cheesed Out Anime 1.2, Chillout Nebula 2.0, Cornflower Stylized Alpha, CyberRealistic v1.3, Dainty Mix Hentai Model v1.5, Dark Souls Diffusion v1.3, Dark Sushi Mix, Dosmix, Experience 7.0,<br>Galaxy Time Machines v3 Pruned, Icomix 0.4, Maple Syrup 1.0, MCQ Ani 1.0, MCQ 1.0, Nostalgia Clear, Pastel Boys 2D, Pegasus 9 Mix, Realistic Experience, Replicant 2.0, Rev Animated 1.1, Rev Animated 1.2.1, RPG v4, Simpmaker 3K, Something v2, Stablydiffuseds Aesthetic Mix,<br>Starlike 1.0, TMND Mix Plus, Uber Realistic Porn Maker</td></tr></tbody></table><a href="https://i.ibb.co/61tqDn5/vae-grid-realistic.png">VAE comparison grid (realistic)</a> --- <a href="https://i.ibb.co/m6VqJH7/vae-grid-anime.png">VAE comparison grid (anime)</a></details>
Model = "Color Bomb Mix (No EMA) (fp16)" #@param ["526 Mix", "7th Anime v3.c", "80's Dark Souls Vibe", "8528 Diffusion", "A Certain Model", "A Certain Thing", "A Certainty", "Abyss 7th Layer", "Abyss Orange Mix 2 HARD", "Abyss Orange Mix 2 NSFW", "Abyss Orange Mix 3", "Abyss Orange Mix 3 A1", "Abyss Orange Mix 3 A1 B", "Abyss Orange Mix 3 A2", "Abyss Orange Mix 3 A3", "Alfamix", "All In One Pixel Model", "Amixx", "Analog Diffusion", "AniFlatMixAnimeFlatColorStyle v2.0", "AniRealityMix v1.0", "Animatrix v2.0", "Anime Pastel Dream Hard (baked vae)", "AnyHentai v2.0", "Anylora (baked vae)", "Anything Gape (fp16)", "Anything v3.0", "Anything v4.5", "Anything v5", "Arcane Diffusion v3.0", "Babes Blend v1.1", "Berry Mix 1.5", "Bra v4", "Cafe Instagram v6.0", "Cardos Animated v2.0", "Cardos Anime v2.0", "Cetus Mix v3.1", "Cheese Daddy's Landscapes Mix v3.5", "Cheesed Out Anime v1.2", "Chillout Mix (Pruned) (fp32)", "Chillout Nebula v2.0", "Cinematic Diffusion", "Cocoa", "Color Bomb Mix (No EMA) (fp16)", "Colorful v3.0", "Comic Diffusion v2.0", "Comics Blend v1.0", "Complex Lineart", "Cool Japan Diffusion v2.1", "Cornflower Stylized Alpha", "Counterfeit v2.0 (fp16)", "Counterfeit v2.5 (Pruned)", "CyberRealistic v1.3", "Cyberpunk Anime Diffusion", "Dainty Mix Hentai Model v1.5", "Dark Souls Diffusion v1.3", "Dark Sushi Mix Brighter (Pruned)", "Defmix v2.0", "Deliberate v2.0", "Divine Elegance Mix v5.0", "Dosmix", "Dpepmkmp", "Dream Like Sam Kuvshino", "Dreamlike Diffusion v1.0", "Dreamlike Photoreal v2.0", "Dreamshaper v3.32 Clip Fix (baked vae)", "Dreamshaper v5.0 (baked vae)", "DucHaiten AI Art v2.0", "DucHaiten AI Art v4.5.3", "DucHaiten God Of Simp v0.2", "Eimis Anime Diffusion v1.0v", "Eimis Anime Model v2.0", "Elldreth's Lucid Mix v1.0", "Elysium Anime v2.0", "Elysium Anime v3.0", "Experience v7.0", "F222", "Face Bomb Mix (fp16) (No EMA)", "Faetastic v1.0", "Fantasy World v1.0", "Feelyou Alpha 1", "Flat 2D Animerge v1.0", "Food Crit", "Galaxy Time Machines v3.0 (Pruned)", "Grapefruit", "Graphic Art Beta 11", "HasDX (EMA Only)", "Hassaku Hentai Model v1.1", "Hassan Blend v1.4", "Hassan Blend v1.5.1.2", "Hyper Bomb Mix (fp16) (No EMA)", "Icomix v0.4", "Illuminati v1.1", "Illustration Diffusion", "Inkpunk v2.0", "Izumi v0.1", "Knollingcase", "Liberty", "Lucky Strike Mix Realistic v0.2", "Lyriel v1.5", "MCQ Ani v1.0", "MCQ v1.0", "Magical Mix v1.0", "Magical Mix v2.0", "Maple Syrup v1.0", "Mare Coloris", "Meina Mix v8.0 (baked vae)", "Midjourney v4.0", "Mistoon Anime v1.0", "Mix Pro v4.0", "Mo Di Diffusion v1.0 (Pruned)", "Monstermash 4 + Anything v3.0", "Monstermash 6 + Anything v3.0", "Mousey Mix", "Needyou Alpha 2", "Neverending Dream (baked vae)", "Nostalgia Clear", "Open Anime Journey", "Open Journey v2.0", "Open Journey v4.0", "Orange Cocoa Mix 2 HARD", "PVC v3.0 (fp32)", "Padoru v1.0", "Papercut Diffusion v1.0", "Pastel Boys 2D v2.0", "Pastel Mix Stylized Anime (fp16)", "Pastel Mix Stylized Anime (fp32)", "Pegasus 9 Mix v1.0", "Perfect World v2 (baked vae)", "Photorealostic Fuen v1.0", "Pony Diffusion v2.0", "Pony Diffusion v3.0", "Pony Diffusion v4.0", "Popup Book Diffusion v1.0", "Protogen Nova", "Protogen X v3.4", "Protogen v2.2", "RPG v4.0", "Rando mix 3", "Realbiter v1.0", "Realistic Experience", "Realistic Vision v1.3", "Realistic Vision v2.0", "RefSlave v2.0", "Replicant v2.0", "Rev Animated v1.1", "Rev Animated v1.2.1", "Riffusion v1.0", "Rmada Merge v5.0", "Rmadart v5.0", "Robo Diffusion v1.0", "SamDoesArt v3.0", "SamDoesSexy Blend", "Seek Art Mega v1.0", "Seek Art Mega v2.0", "Simpmaker 3k", "Something v2.0", "Stable Diffusion v1.4", "Stable Diffusion v1.5 (Pruned) (EMA Only)", "Stable Diffusion v1.5 Inpainting", "Stable Diffusion v2.0 (EMA Only)", "Stable Diffusion v2.0 Base (EMA Only)", "Stable Diffusion v2.0 Depth (EMA Only)", "Stable Diffusion v2.0 Inpainting (EMA Only)", "Stable Diffusion v2.1 (Pruned) (EMA Only)", "Stable Diffusion v2.1 Base (Pruned) (EMA Only)", "Stablydiffuseds Aesthetic Mix v2.6", "Starlike v1.0", "Sukiyaki Mix v1.0", "Synthwave Punk v2.0", "TMND Mix Plus", "Toonyou Alpha 3", "Uber Realistic Porn Maker v1.0 (EMA Only)", "Uber Realistic Porn Merge v1.3", "Van Gogh Diffusion", "Vinte Protogen Mix v1.0", "Vintedois Diffusion v0.1", "Voxo v0.0", "Waifu Diffusion v1.3 (fp32)", "Waifu Diffusion v1.4-anime-e1", "Waifu Diffusion v1.5 beta 1 (fp32)", "Waifu Diffusion v1.5 beta 2 (fp32)", "Waifu Diffusion v1.5 beta 2 Aesthetic (fp32)", "Woolitize", "Xrikishi's Unstable Alpha 6", "Yiffy E18", "Yiffy Mix", "Yohan Diffusion"]
#@markdown ___
#@markdown ##*Extensions*
#@markdown <details><summary>Click here to show/hide links to extensions' homepages</summary><a href="https://github.com/nonnonstop/sd-webui-3d-open-pose-editor">3D Openpose Editor</a> --- <a href="https://github.com/kohya-ss/sd-webui-additional-networks">Additional Networks</a> --- <a href="https://github.com/etherealxx/batchlinks-webui">Batchlinks Downloader</a> --- <a href="https://github.com/catppuccin/catppuccin">Catpuccin</a> --- <a href="https://github.com/camenduru/sd-civitai-browser">CivitAI Browser</a> --- <a href="https://github.com/Mikubill/sd-webui-controlnet">ControlNet</a> --- <a href="https://github.com/deforum-art/deforum-for-automatic1111-webui">Deforum</a> --- <a href="https://github.com/jexom/sd-webui-depth-lib">Depth Map Library</a> --- <a href="https://shorturl.at/aopS6">Huggingface</a> --- <a href="https://shorturl.at/jsuBM">Images Browser</a> --- <a href="https://shorturl.at/dqU03">Instruct Pix2Pix</a> --- <a href="https://github.com/KohakuBlueleaf/a1111-sd-webui-locon">Locon</a> --- <a href="https://github.com/KohakuBlueleaf/a1111-sd-webui-lycoris">Lycoris</a> --- <a href="https://github.com/camenduru/openpose-editor">OpenPose Editor</a> --- <a href="https://github.com/hnmr293/posex">PoseX</a> --- <a href="https://shorturl.at/hxI25">RemBG</a> --- <a href="https://shorturl.at/cHJR8">Run N Times</a> --- <a href="https://shorturl.at/iQY16">Two-Shot</a></details>
_3d_openpose_editor = True #@param {type:"boolean"}
additional_networks = True #@param {type:"boolean"}
batchlinks_downloader = True #@param {type:"boolean"}
catpuccin = True #@param {type:"boolean"}
civitai_browser = True #@param {type:"boolean"}
controlnet_v1_1 = True #@param {type:"boolean"}
deforum = True #@param {type:"boolean"}
depth_library = True #@param {type:"boolean"}
huggingface = True #@param {type:"boolean"}
images_browser = True #@param {type:"boolean"}
instruct_pix2pix_model = True #@param {type:"boolean"}
#@markdown <sub><a href="https://github.com/KohakuBlueleaf/a1111-sd-webui-locon/issues/11#issuecomment-1475085476">The following locon extension can not hook additional networks at the moment</a>, meaning you can't use LoCon/LoHA with additional networks enabled. It's recommended to use lycoris instead.</sub>
locon = True #@param {type:"boolean"}
lycoris = True #@param {type:"boolean"}
openpose_editor = True #@param {type:"boolean"}
posex = True #@param {type:"boolean"}
rembg = True #@param {type:"boolean"}
run_n_times_script = True #@param {type:"boolean"}
two_shot = True #@param {type:"boolean"}
#@markdown ___
#@markdown ##*Negative embeddings*
bad_artist = True #@param {type:"boolean"}
bad_artist_anime = True #@param {type:"boolean"}
bad_hands_5 = True #@param {type:"boolean"}
bad_image_v2_39000 = True #@param {type:"boolean"}
bad_prompt = True #@param {type:"boolean"}
bad_prompt_version2 = True #@param {type:"boolean"}
easynegative = True #@param {type:"boolean"}
unspeakable_horrors_64 = True #@param {type:"boolean"}
ng_deepnegative_v1_75t = True #@param {type:"boolean"}
#@markdown ___
#@markdown ##*Positive LoRAs*
epi_noise_offset_v2 = True #@param {type:"boolean"}
animeLineartMangaLike_v30MangaLike = True #@param {type:"boolean"}
#@markdown ___
#@markdown ##*VAEs*
anything_v3 = True #@param {type:"boolean"}
anything_v4 = True #@param {type:"boolean"}
grapefruit = True #@param {type:"boolean"}
kl_f8_anime2 = True #@param {type:"boolean"}
orangemix = True #@param {type:"boolean"}
randomix_3 = True #@param {type:"boolean"}
refslave = True #@param {type:"boolean"}
#@markdown ___
#@markdown ##*Additional upscalers*
_4x_ultra_sharp = True #@param {type:"boolean"}
##@markdown ___
##@markdown ##*Choose a service to host the webui*
#tunnel = "Cloudflare" #@param ["Cloudflare", "Gradio", "Remote.moe"]
#@markdown ___
#@markdown ##*Uncheck to launch webui without dark theme*
dark_theme = True #@param {type:'boolean'}

#####################
##### SHORTCUTS #####
#####################
bypass = "stable-" + "diffusion-" + "webui"
root_folder = "/content/" + bypass
models_folder = root_folder + "/models/Stable-diffusion"
ctrlnet_url = "https://huggingface.co/ckpt/ControlNet-v1-1/resolve/main"
ctrlnet_yaml_url = "https://huggingface.co/ckpt/ControlNet-v1-1/raw/main"
ctrlnet_folder = root_folder + "/extensions/sd-webui-controlnet/models"
embeds_folder = root_folder + "/embeddings"
neg_embeds_folder = embeds_folder + "/negative"
pos_loras_folder = root_folder + "/models/Lora/positive"
pos_loras_addnet_folder = root_folder + "/extensions/sd-webui-additional-networks/models/lora/positive"
vaes_folder = root_folder + "/models/VAE"
upscalers_folder = root_folder + "/models/ESRGAN"
aria_args = "-q -c -x 16 -s 16 -k 1M"

###################################
##### DICTIONNARIES AND LISTS #####
###################################

# Extensions repositories dictionnary

repos_dict = {
    "a1111-sd-webui-locon": {
        "repo": "https://github.com/KohakuBlueleaf/a1111-sd-webui-locon",
        "branch": "main",
        "subfolder": "extensions",
        "command": "clone",
        "value": locon
    },
    "a1111-sd-webui-lycoris": {
        "repo": "https://github.com/KohakuBlueleaf/a1111-sd-webui-lycoris",
        "branch": "main",
        "subfolder": "extensions",
        "command": "clone",
        "value": lycoris
    },
    "batchlinks-webui": {
        "repo": "https://github.com/etherealxx/batchlinks-webui",
        "branch": "main",
        "subfolder": "extensions",
        "command": "clone",
        "value": batchlinks_downloader
    },
    "deforum-for-automatic1111-webui": {
        "repo": "https://github.com/deforum-art/deforum-for-automatic1111-webui",
        "branch": "main",
        "subfolder": "extensions",
        "command": "clone",
        "value": deforum
    },
    "instruct-pix2pix-00-22000.safetensors": {
        "repo": "https://huggingface.co/timbrooks/instruct-pix2pix/resolve/main/instruct-pix2pix-00-22000.safetensors",
        "branch": "",
        "subfolder": "models/Stable-diffusion",
        "command": "aria2",
        "value": instruct_pix2pix_model
    },
    "openpose-editor": {
        "repo": "https://github.com/fkunn1326/openpose-editor",
        "branch": "master",
        "subfolder": "extensions",
        "command": "clone",
        "value": openpose_editor
    },
    "posex": {
        "repo": "https://github.com/hnmr293/posex",
        "branch": "master",
        "subfolder": "extensions",
        "command": "clone",
        "value": posex
    },
    "run_n_times.py": {
        "repo": "https://raw.githubusercontent.com/camenduru/" + bypass + "-scripts/main/run_n_times.py",
        "branch": "",
        "subfolder": "scripts",
        "command": "aria2",
        "value": run_n_times_script
    },
    "sd-civitai-browser": {
        "repo": "https://github.com/camenduru/sd-civitai-browser",
        "branch": "main",
        "subfolder": "extensions",
        "command": "clone",
        "value": civitai_browser
    },
    "sd-webui-3d-open-pose-editor": {
        "repo": "https://github.com/nonnonstop/sd-webui-3d-open-pose-editor",
        "branch": "main",
        "subfolder": "extensions",
        "command": "clone",
        "value": _3d_openpose_editor
    },
    "sd-webui-additional-networks": {
        "repo": "https://github.com/kohya-ss/sd-webui-additional-networks",
        "branch": "main",
        "subfolder": "extensions",
        "command": "clone",
        "value": additional_networks
    },
    "sd-webui-controlnet": {
        "repo": "https://github.com/Mikubill/sd-webui-controlnet",
        "branch": "main",
        "subfolder": "extensions",
        "command": "clone",
        "value": controlnet_v1_1
    },
    "sd-webui-depth-lib": {
        "repo": "https://github.com/jexom/sd-webui-depth-lib",
        "branch": "main",
        "subfolder": "extensions",
        "command": "clone",
        "value": depth_library
    },
    bypass + "-catpuccin": {
        "repo": "https://github.com/catppuccin/" + bypass,
        "branch": "main",
        "subfolder": "extensions",
        "command": "clone",
        "value": catpuccin
    },
    bypass + "-huggingface": {
        "repo": "https://github.com/camenduru/" + bypass + "-huggingface",
        "branch": "main",
        "subfolder": "extensions",
        "command": "clone",
        "value": huggingface
    },
    bypass + "-images-browser": {
        "repo": "https://github.com/AlUlkesh/" + bypass + "-images-browser",
        "branch": "main",
        "subfolder": "extensions",
        "command": "clone",
        "value": images_browser
    },
    bypass + "-rembg": {
        "repo": "https://github.com/AUTOMATIC1111/" + bypass + "-rembg",
        "branch": "master",
        "subfolder": "extensions",
        "command": "clone",
        "value": rembg
    },
    bypass + "-two-shot": {
        "repo": "https://github.com/ashen-sensored/" + bypass + "-two-shot",
        "branch": "main",
        "subfolder": "extensions",
        "command": "clone",
        "value": two_shot
    }
}
# ControlNet list

ctrlnet_list = [
    "control_v11e_sd15_ip2p_fp16.safetensors",
    "control_v11e_sd15_shuffle_fp16.safetensors",
    "control_v11p_sd15_canny_fp16.safetensors",
    "control_v11f1p_sd15_depth_fp16.safetensors",
    "control_v11p_sd15_inpaint_fp16.safetensors",
    "control_v11p_sd15_lineart_fp16.safetensors",
    "control_v11p_sd15_mlsd_fp16.safetensors",
    "control_v11p_sd15_normalbae_fp16.safetensors",
    "control_v11p_sd15_openpose_fp16.safetensors",
    "control_v11p_sd15_scribble_fp16.safetensors",
    "control_v11p_sd15_seg_fp16.safetensors",
    "control_v11p_sd15_softedge_fp16.safetensors",
    "control_v11p_sd15s2_lineart_anime_fp16.safetensors",
    "control_v11f1e_sd15_tile_fp16.safetensors",
    "t2iadapter_style_sd14v1.pth",
    "t2iadapter_sketch_sd14v1.pth",
    "t2iadapter_seg_sd14v1.pth",
    "t2iadapter_openpose_sd14v1.pth",
    "t2iadapter_keypose_sd14v1.pth",
    "t2iadapter_depth_sd14v1.pth",
    "t2iadapter_color_sd14v1.pth",
    "t2iadapter_canny_sd14v1.pth",
    "t2iadapter_canny_sd15v2.pth",
    "t2iadapter_depth_sd15v2.pth",
    "t2iadapter_sketch_sd15v2.pth",
    "t2iadapter_zoedepth_sd15v1.pth"
]

ctrlnet_yaml_list = [
    "control_v11e_sd15_ip2p_fp16.yaml",
    "control_v11e_sd15_shuffle_fp16.yaml",
    "control_v11p_sd15_canny_fp16.yaml",
    "control_v11f1p_sd15_depth_fp16.yaml",
    "control_v11p_sd15_inpaint_fp16.yaml",
    "control_v11p_sd15_lineart_fp16.yaml",
    "control_v11p_sd15_mlsd_fp16.yaml",
    "control_v11p_sd15_normalbae_fp16.yaml",
    "control_v11p_sd15_openpose_fp16.yaml",
    "control_v11p_sd15_scribble_fp16.yaml",
    "control_v11p_sd15_seg_fp16.yaml",
    "control_v11p_sd15_softedge_fp16.yaml",
    "control_v11p_sd15s2_lineart_anime_fp16.yaml",
    "control_v11f1e_sd15_tile_fp16.yaml"
]

# Models dictionnary

models_dict = {
    "526 Mix": {
        "model_url": "https://civitai.com/api/download/models/19790",
        "model_file": "526mixExperimental_v12.safetensors"
    },
    "7th Anime v3.c": {
        "model_url": "https://huggingface.co/syaimu/7th_Layer/resolve/main/7th_anime_v3/7th_anime_v3_C.safetensors",
        "model_file": "7th_anime_v3_C.safetensors"
    },
    "80's Dark Souls Vibe": {
        "model_url": "https://huggingface.co/ckpt/80sdarksoulsvibes/resolve/main/80sdarksoulsvibes_v1.ckpt",
        "model_file": "80sdarksoulsvibes_v1.ckpt"
    },
    "8528 Diffusion": {
        "model_url": "https://huggingface.co/ckpt/8528-diffusion/resolve/main/8528d-final.ckpt",
        "model_file": "8528d-final.ckpt"
    },
    "A Certain Model": {
        "model_url": "https://huggingface.co/ckpt/ACertainModel/resolve/main/ACertainModel.ckpt",
        "model_file": "ACertainModel.ckpt"
    },
    "A Certain Thing": {
        "model_url": "https://huggingface.co/ckpt/ACertainThing/resolve/main/ACertainThing.ckpt",
        "model_file": "ACertainThing.ckpt"
    },
    "A Certainty": {
        "model_url": "https://huggingface.co/ckpt/ACertainty/resolve/main/ACertainty.ckpt",
        "model_file": "ACertainty.ckpt"
    },
    "Abyss 7th Layer": {
        "model_url": "https://huggingface.co/syaimu/7th_Layer/resolve/main/7th_layer/Abyss_7th_layer.ckpt",
        "model_file": "Abyss_7th_layer.ckpt"
    },
    "Abyss Orange Mix 2 HARD": {
        "model_url": "https://huggingface.co/WarriorMama777/OrangeMixs/resolve/main/Models/AbyssOrangeMix2/AbyssOrangeMix2_hard.safetensors",
        "model_file": "AbyssOrangeMix2_hard.safetensors",
        "vae": "anything_v3"
    },
    "Abyss Orange Mix 2 NSFW": {
        "model_url": "https://huggingface.co/WarriorMama777/OrangeMixs/resolve/main/Models/AbyssOrangeMix2/AbyssOrangeMix2_nsfw.safetensors",
        "model_file": "AbyssOrangeMix2_nsfw.safetensors",
        "vae": "anything_v3"
    },
    "Abyss Orange Mix 3": {
        "model_url": "https://huggingface.co/WarriorMama777/OrangeMixs/resolve/main/Models/AbyssOrangeMix3/AOM3_orangemixs.safetensors",
        "model_file": "AOM3_orangemixs.safetensors",
        "vae": "orangemix"
    },
    "Abyss Orange Mix 3 A1": {
        "model_url": "https://huggingface.co/WarriorMama777/OrangeMixs/resolve/main/Models/AbyssOrangeMix3/AOM3A1_orangemixs.safetensors",
        "model_file": "AOM3A1_orangemixs.safetensors",
        "vae": "orangemix"
    },
    "Abyss Orange Mix 3 A1 B": {
        "model_url": "https://huggingface.co/WarriorMama777/OrangeMixs/resolve/main/Models/AbyssOrangeMix3/AOM3A1B_orangemixs.safetensors",
        "model_file": "AOM3A1B_orangemixs.safetensors",
        "vae": "orangemix"
    },
    "Abyss Orange Mix 3 A2": {
        "model_url": "https://huggingface.co/WarriorMama777/OrangeMixs/resolve/main/Models/AbyssOrangeMix3/AOM3A2_orangemixs.safetensors",
        "model_file": "AOM3A2_orangemixs.safetensors",
        "vae": "orangemix"
    },
    "Abyss Orange Mix 3 A3": {
        "model_url": "https://huggingface.co/WarriorMama777/OrangeMixs/resolve/main/Models/AbyssOrangeMix3/AOM3A3_orangemixs.safetensors",
        "model_file": "AOM3A3_orangemixs.safetensors",
        "vae": "orangemix"
    },
    "Alfamix": {
        "model_url": "'https://civitai.com/api/download/models/17792?type=Model&format=SafeTensor'",
        "model_file": "alfamix_V1.safetensors"
    },
    "All In One Pixel Model": {
        "model_url": "https://huggingface.co/ckpt/All-In-dne-Pixel-Model/resolve/main/Public-Prompts-Pixel-Model.ckpt",
        "model_file": "Public-Prompts-Pixel-Model.ckpt"
    },
    "Amixx": {
        "model_url": "https://huggingface.co/ckpt/amixx/resolve/main/amixx_v10.safetensors",
        "model_file": "amixx_v10.safetensors"
    },
    "Analog Diffusion": {
        "model_url": "https://huggingface.co/ckpt/Analog-Diffusion/resolve/main/analog-diffusion-1.0.ckpt",
        "model_file": "analog-diffusion-1.0.ckpt"
    },
    "AniFlatMixAnimeFlatColorStyle v2.0": {
        "model_url": "https://huggingface.co/ckpt/aniflatmix-anime-flat-color-style-mix/resolve/main/aniflatmixAnimeFlatColorStyle_v20.safetensors",
        "model_file": "aniflatmixAnimeFlatColorStyle_v20.safetensors"
    },
    "AniRealityMix v1.0": {
        "model_url": "https://huggingface.co/ckpt/anireality-mix/resolve/main/anirealityMix_v1.safetensors",
        "model_file": "anirealityMix_v1.safetensors",
        "vae": "kl_f8_anime2"
    },
    "Animatrix v2.0": {
        "model_url": "https://huggingface.co/ckpt/animatrix/resolve/main/animatrix_v20.safetensors",
        "model_file": "animatrix_v20.safetensors"
    },
    "Anime Pastel Dream Hard (baked vae)": {
        "model_url": "https://huggingface.co/ckpt/anime-pastel-dream/resolve/main/animePastelDream_hardBakedVae.safetensors",
        "model_file": "animePastelDream_hardBakedVae.safetensors"
    },
    "AnyHentai v2.0": {
        "model_url": "https://huggingface.co/ckpt/anyhentai/resolve/main/anyhentai_20.safetensors",
        "model_file": "anyhentai_20.safetensors"
    },
    "Anylora (baked vae)": {
        "model_url": "https://huggingface.co/ckpt/anylora/resolve/main/anyloraCheckpoint_bakedvaeFtmseFp16NOT.safetensors",
        "model_file": "anyloraCheckpoint_bakedvaeFtmseFp16NOT.safetensors"
    },
    "Anything Gape (fp16)": {
        "model_url": "https://huggingface.co/ckpt/AnyGape/resolve/main/AnythingGape-fp16.ckpt",
        "model_file": "AnythingGape-fp16.ckpt"
    },
    "Anything v3.0": {
        "model_url": "https://huggingface.co/ckpt/anything-v3.0/resolve/main/Anything-V3.0-pruned.ckpt",
        "model_file": "Anything-V3.0-pruned.ckpt",
        "vae": "anything_v3"
    },
    "Anything v4.5": {
        "model_url": "https://huggingface.co/ckpt/anything-v4.0/resolve/main/anything-v4.5-pruned.ckpt",
        "model_file": "anything-v4.5-pruned.ckpt",
        "vae": "anything_v4"
    },
    "Anything v5": {
        "model_url": "https://huggingface.co/ckpt/anything-v5.0/resolve/main/AnythingV5V3_v5PrtRE.safetensors",
        "model_file": "AnythingV5V3_v5PrtRE.safetensors",
        "vae": "anything_v4"
    },
    "Arcane Diffusion v3.0": {
        "model_url": "https://huggingface.co/ckpt/Arcane-Diffusion/resolve/main/arcane-diffusion-v3.ckpt",
        "model_file": "arcane-diffusion-v3.ckpt"
    },
    "Babes Blend v1.1": {
        "model_url": "https://huggingface.co/ckpt/babes/resolve/main/babes_11.safetensors",
        "model_file": "babes_11.safetensors"
    },
    "Berry Mix 1.5": {
        "model_url": "https://huggingface.co/ckpt/rbm/resolve/main/rbm.ckpt",
        "model_file": "rbm.ckpt"
    },
    "Bra v4": {
        "model_url": "https://huggingface.co/ckpt/BraV4/resolve/main/BraV4.safetensors",
        "model_file": "BraV4.safetensors"
    },
    "Cafe Instagram v6.0": {
        "model_url": "https://huggingface.co/ckpt/cafe-instagram-sd-1-5-v6/resolve/main/instagram-latest-plus-clip-v6e1_50000.safetensors",
        "model_file": "instagram-latest-plus-clip-v6e1_50000.safetensors"
    },
    "Cardos Animated v2.0": {
        "model_url": "https://huggingface.co/ckpt/cardos-animated/resolve/main/cardosAnimated_v20.safetensors",
        "model_file": "cardosAnimated_v20.safetensors"
    },
    "Cardos Anime v2.0": {
        "model_url": "https://huggingface.co/ckpt/cardos-anime/resolve/main/cardosAnime_v20.safetensors",
        "model_file": "cardosAnime_v20.safetensors"
    },
    "Cetus Mix v3.1": {
        "model_url": "https://civitai.com/api/download/models/20229",
        "model_file": "cetusMix_Codaedition.safetensors"
    },
    "Cheese Daddy's Landscapes Mix v3.5": {
        "model_url": "https://huggingface.co/ckpt/cheese-daddys-landscapes-mix/resolve/main/cheeseDaddys_35.safetensors",
        "model_file": "cheeseDaddys_35.safetensors"
    },
    "Cheesed Out Anime v1.2": {
        "model_url": "https://huggingface.co/ckpt/cheesed-out-anime-backgrounds/resolve/main/cheesedOutAnime_v12.safetensors",
        "model_file": "cheesedOutAnime_v12.safetensors"
    },
    "Chillout Mix (Pruned) (fp32)": {
        "model_url": "https://huggingface.co/ckpt/chilloutmix/resolve/main/chilloutmix_NiPrunedFp32Fix.safetensors",
        "model_file": "chilloutmix_NiPrunedFp32Fix.safetensors"
    },
    "Chillout Nebula v2.0": {
        "model_url": "https://huggingface.co/ckpt/chilloutnebula/resolve/main/chilloutnebula_20.safetensors",
        "model_file": "chilloutnebula_20.safetensors"
    },
    "Cinematic Diffusion": {
        "model_url": "https://huggingface.co/ckpt/Cinematic-Diffusion/resolve/main/syberart.ckpt",
        "model_file": "syberart.ckpt"
    },
    "Cocoa": {
        "model_url": "https://huggingface.co/ckpt/yohan-diffusion/resolve/main/Cocoa.ckpt",
        "model_file": "Cocoa.ckpt",
        "vae": "anything_v3"
    },
    "Color Bomb Mix (No EMA) (fp16)": {
        "model_url": "https://huggingface.co/mocker/KaBoom/resolve/main/ColorBombMix-fp16-no-ema.safetensors",
        "model_file": "ColorBombMix-fp16-no-ema.safetensors",
        "vae": "kl_f8_anime2"
    },
    "Colorful v3.0": {
        "model_url": "https://huggingface.co/ckpt/colorful/resolve/main/colorful_v30.safetensors",
        "model_file": "colorful_v30.safetensors"
    },
    "Comic Diffusion v2.0": {
        "model_url": "https://huggingface.co/ckpt/Comic-Diffusion/resolve/main/comic-diffusion-V2.ckpt",
        "model_file": "comic-diffusion-V2.ckpt"
    },
    "Comics Blend v1.0": {
        "model_url": "https://huggingface.co/ckpt/comicsblend/resolve/main/comicsblend_V1.ckpt",
        "model_file": "comicsblend_V1.ckpt"
    },
    "Complex Lineart": {
        "model_url": "https://huggingface.co/ckpt/Complex-Lineart/resolve/main/ComplexLA%20Style.ckpt",
        "model_file": "ComplexLA_Style.ckpt"
    },
    "Cool Japan Diffusion v2.1": {
        "model_url": "https://huggingface.co/ckpt/cool-japan-diffusion-2-1-0/resolve/main/v2-1-0.ckpt",
        "model_file": "v2-1-0.ckpt",
        "yaml_url": "https://huggingface.co/ckpt/cool-japan-diffusion-2-1-0/raw/main/v2-1-0.yaml",
        "yaml_file": "v2-1-0.yaml"
    },
    "Cornflower Stylized Alpha": {
        "model_url": "https://huggingface.co/ckpt/cornflower-d-stylized-semi-realistic-model/resolve/main/WIPCornflowerDStylized_alpha.ckpt",
        "model_file": "WIPCornflowerDStylized_alpha.ckpt"
    },
    "Counterfeit v2.0 (fp16)": {
        "model_url": "https://huggingface.co/ckpt/Counterfeit-V2.0/resolve/main/Counterfeit-V2.0fp16.safetensors",
        "model_file": "Counterfeit-V2.0fp16.safetensors",
        "vae": "anything_v3"
    },
    "Counterfeit v2.5 (Pruned)": {
        "model_url": "https://huggingface.co/gsdf/Counterfeit-V2.5/resolve/main/Counterfeit-V2.5_pruned.safetensors",
        "model_file": "Counterfeit-V2.5_pruned.safetensors",
        "vae": "anything_v3"
    },
    "CyberRealistic v1.3": {
        "model_url": "https://huggingface.co/ckpt/CyberRealistic/resolve/main/cyberrealistic_v13.safetensors",
        "model_file": "cyberrealistic_v13.safetensors"
    },
    "Cyberpunk Anime Diffusion": {
        "model_url": "https://huggingface.co/ckpt/Cyberpunk-Anime-Diffusion/resolve/main/Cyberpunk-Anime-Diffusion.ckpt",
        "model_file": "Cyberpunk-Anime-Diffusion.ckpt"
    },
    "Dainty Mix Hentai Model v1.5": {
        "model_url": "https://huggingface.co/ckpt/daintymix/resolve/main/daintymixHentaiModel_v15.safetensors",
        "model_file": "daintymixHentaiModel_v15.safetensors"
    },
    "Dark Souls Diffusion v1.3": {
        "model_url": "https://huggingface.co/ckpt/dark-souls-diffusion/blob/main/darkSoulsDiffusion_v13.ckpt",
        "model_file": "darkSoulsDiffusion_v13.ckpt"
    },
    "Dark Sushi Mix Brighter (Pruned)": {
        "model_url": "https://huggingface.co/ckpt/dark-sushi-mix-mix/resolve/main/darkSushiMixMix_brighterPruned.safetensors",
        "model_file": "darkSushiMixMix_brighterPruned.safetensors"
    },
    "Defmix v2.0": {
        "model_url": "https://huggingface.co/Defpoint/Defmix-v2.0/resolve/main/Defmix-v2.0.safetensors",
        "model_file": "Defmix-v2.0.safetensors",
        "vae": "kl_f8_anime2"
    },
    "Deliberate v2.0": {
        "model_url": "https://huggingface.co/XpucT/Deliberate/resolve/main/Deliberate_v2.safetensors",
        "model_file": "Deliberate_v2.safetensors"
    },
    "Divine Elegance Mix v5.0": {
        "model_url": "https://huggingface.co/ckpt/divineelegancemix/resolve/main/divineelegancemix_V5.safetensors",
        "model_file": "divineelegancemix_V5.safetensors"
    },
    "Dosmix": {
        "model_url": "https://huggingface.co/ckpt/dosmix/resolve/main/dosmix_.safetensors",
        "model_file": "dosmix_.safetensors"
    },
    "Dpepmkmp": {
        "model_url": "https://huggingface.co/closertodeath/dpepmkmp/resolve/main/dpepmkmp.safetensors",
        "model_file": "dpepmkmp.safetensors",
        "vae": "kl_f8_anime2"
    },
    "Dream Like Sam Kuvshino": {
        "model_url": "https://huggingface.co/ckpt/dreamlikesamkuvshinov/resolve/main/dreamlikesamkuvshino.safetensors",
        "model_file": "dreamlikesamkuvshino.safetensors"
    },
    "Dreamlike Diffusion v1.0": {
        "model_url": "https://huggingface.co/ckpt/dreamlike-diffusion-1.0/resolve/main/dreamlike-diffusion-1.0.ckpt",
        "model_file": "dreamlike-diffusion-1.0.ckpt"
    },
    "Dreamlike Photoreal v2.0": {
        "model_url": "https://huggingface.co/ckpt/dreamlike-photoreal-2.0/resolve/main/dreamlike-photoreal-2.0.safetensors",
        "model_file": "dreamlike-photoreal-2.0.safetensors"
    },
    "Dreamshaper v3.32 Clip Fix (baked vae)": {
        "model_url": "https://huggingface.co/Lykon/DreamShaper/resolve/main/Dreamshaper_3.32_baked_vae_clip_fix.safetensors",
        "model_file": "Dreamshaper_3.32_baked_vae_clip_fix.safetensors"
    },
    "Dreamshaper v5.0 (baked vae)": {
        "model_url": "https://huggingface.co/ckpt/dreamshaper/resolve/main/dreamshaper_5BakedVae.safetensors",
        "model_file": "dreamshaper_5BakedVae.safetensors"
    },
    "DucHaiten AI Art v2.0": {
        "model_url": "https://huggingface.co/DucHaiten/DucHaitenAIart/resolve/main/DucHaitenAIart_v2.0.safetensors",
        "model_file": "DucHaitenAIart_v2.0.safetensors"
    },
    "DucHaiten AI Art v4.5.3": {
        "model_url": "https://huggingface.co/ckpt/duchaitenaiart/resolve/main/duchaitenaiart_V453.safetensors",
        "model_file": "duchaitenaiart_V453.safetensors"
    },
    "DucHaiten God Of Simp v0.2": {
        "model_url": "https://huggingface.co/ckpt/duchaiten-godofsimp/resolve/main/duchaitenGodofsimp_v02.safetensors",
        "model_file": "duchaitenGodofsimp_v02.safetensors"
    },
    "Eimis Anime Diffusion v1.0v": {
        "model_url": "https://huggingface.co/ckpt/EimisAnimeDiffusion_1.0v/resolve/main/EimisAnimeDiffusion_1-0v.ckpt",
        "model_file": "EimisAnimeDiffusion_1-0v.ckpt"
    },
    "Eimis Anime Model v2.0": {
        "model_url": "https://huggingface.co/ckpt/EimisAnimeDiffusion/resolve/main/EimisAnimeModel_2-0.safetensors",
        "model_file": "EimisAnimeModel_2-0.safetensors"
    },
    "Elldreth's Lucid Mix v1.0": {
        "model_url": "https://huggingface.co/ckpt/elldrethSLucidMix_v10/resolve/main/elldrethSLucidMix_v10.ckpt",
        "model_file": "elldrethSLucidMix_v10.ckpt"
    },
    "Elysium Anime v2.0": {
        "model_url": "https://huggingface.co/ckpt/SD-Elysium-Model/resolve/main/Elysium_Anime_V2.ckpt",
        "model_file": "Elysium_Anime_V2.ckpt",
        "vae": "kl_f8_anime2"
    },
    "Elysium Anime v3.0": {
        "model_url": "https://huggingface.co/ckpt/SD-Elysium-Model/resolve/main/Elysium_Anime_V3.safetensors",
        "model_file": "Elysium_Anime_V3.safetensors",
        "vae": "kl_f8_anime2"
    },
    "Experience v7.0": {
        "model_url": "https://huggingface.co/Schisim/Experience/resolve/main/eXp_7.0.safetensors",
        "model_file": "eXp_7.0.safetensors"
    },
    "F222": {
        "model_url": "https://huggingface.co/ckpt/f2/resolve/main/f2.ckpt",
        "model_file": "f2.ckpt"
    },
    "Face Bomb Mix (fp16) (No EMA)": {
        "model_url": "https://huggingface.co/mocker/KaBoom/resolve/main/FaceBombMix-fp16-no-ema.safetensors",
        "model_file": "FaceBombMix-fp16-no-ema.safetensors",
        "vae": "kl_f8_anime2"
    },
    "Faetastic v1.0": {
        "model_url": "https://huggingface.co/ckpt/FaeTastic/resolve/main/faetastic_.safetensors",
        "model_file": "faetastic_.safetensors",
        "vae": "kl_f8_anime2"
    },
    "Fantasy World v1.0": {
        "model_url": "https://huggingface.co/ckpt/fantasy-world/resolve/main/fantasyWorld_v1.safetensors",
        "model_file": "fantasyWorld_v1.safetensors",
        "vae": "kl_f8_anime2"
    },
    "Feelyou Alpha 1": {
        "model_url": "https://huggingface.co/ckpt/feelyou/resolve/main/feelyou_alpha1.safetensors",
        "model_file": "feelyou_alpha1.safetensors"
    },
    "Flat 2D Animerge v1.0": {
        "model_url": "https://huggingface.co/ckpt/flat-2d-animerge/resolve/main/flat2DAnimerge_v10.safetensors",
        "model_file": "flat2DAnimerge_v10.safetensors"
    },
    "Food Crit": {
        "model_url": "https://huggingface.co/ckpt/food-crit/resolve/main/food_crit.ckpt",
        "model_file": "food_crit.ckpt"
    },
    "Galaxy Time Machines v3.0 (Pruned)": {
        "model_url": "https://huggingface.co/ckpt/galaxytimemachines-gtmultimateblendv3/resolve/main/galaxytimemachinesGTM_v3Pruned.safetensors",
        "model_file": "galaxytimemachinesGTM_v3Pruned.safetensors"
    },
    "Grapefruit": {
        "model_url": "https://huggingface.co/ckpt/grapefruit/resolve/main/grapefruit.safetensors",
        "model_file": "grapefruit.safetensors",
        "vae": "grapefruit"
    },
    "Graphic Art Beta 11": {
        "model_url": "'https://civitai.com/api/download/models/19546?type=Model&format=SafeTensor'",
        "model_file": "graphicArt_graphicArtBeta11.safetensors",
        "yaml_url": "'https://civitai.com/api/download/models/19546?type=Config&format=Other'",
        "yaml_file": "graphicArt_graphicArtBeta11.yaml"
    },
    "HasDX (EMA Only)": {
        "model_url": "https://huggingface.co/ckpt/hasdx/resolve/main/hasdx_emaonly.ckpt",
        "model_file": "hasdx_emaonly.ckpt"
    },
    "Hassaku Hentai Model v1.1": {
        "model_url": "https://huggingface.co/ckpt/hassaku-hentai-model/resolve/main/hassakuHentaiModel_v11.safetensors",
        "model_file": "hassakuHentaiModel_v11.safetensors"
    },
    "Hassan Blend v1.4": {
        "model_url": "https://huggingface.co/ckpt/hassanblend1.4/resolve/main/HassanBlend1.4-Pruned.ckpt",
        "model_file": "HassanBlend1.4-Pruned.ckpt"
    },
    "Hassan Blend v1.5.1.2": {
        "model_url": "https://huggingface.co/ckpt/hassanblend/resolve/main/HassanBlend1.5.1.2-pruned.safetensors",
        "model_file": "HassanBlend1.5.1.2-pruned.safetensors"
    },
    "Hyper Bomb Mix (fp16) (No EMA)": {
        "model_url": "https://huggingface.co/mocker/KaBoom/resolve/main/HyperBombMix-fp16-no-ema.safetensors",
        "model_file": "HyperBombMix-fp16-no-ema.safetensors",
        "vae": "kl_f8_anime2"
    },
    "Icomix v0.4": {
        "model_url": "https://huggingface.co/ckpt/icomix/resolve/main/icomix_V04.safetensors",
        "model_file": "icomix_V04.safetensors"
    },
    "Illuminati v1.1": {
        "model_url": "https://civitai.com/api/download/models/13259",
        "model_file": "illuminatiDiffusionV1_v11.safetensors",
        "yaml_url": "https://huggingface.co/IlluminatiAI/Illuminati_Diffusion_v1.0/raw/main/illuminati_diffusion_v1.0.yaml",
        "yaml_file": "illuminatiDiffusionV1_v11.yaml",
        "embeds_lists": {
            "embeds_urls": [
                "https://civitai.com/api/download/models/15927",
                "https://civitai.com/api/download/models/15926",
                "https://civitai.com/api/download/models/15921"
            ],
            "embeds_files": [
                "nrealfixer.pt",
                "nartfixer.pt",
                "nfixer.pt"
            ]
        }
    },
    "Illustration Diffusion": {
        "model_url": "https://huggingface.co/ckpt/Illustration-Diffusion/resolve/main/hollie-mengert.ckpt",
        "model_file": "hollie-mengert.ckpt"
    },
    "Inkpunk v2.0": {
        "model_url": "https://huggingface.co/ckpt/Inkpunk-Diffusion/resolve/main/Inkpunk-Diffusion-v2.ckpt",
        "model_file": "Inkpunk-Diffusion-v2.ckpt"
    },
    "Izumi v0.1": {
        "model_url": "https://huggingface.co/ckpt/iz/resolve/main/izumi_01.ckpt",
        "model_file": "izumi_01.ckpt"
    },
    "Knollingcase": {
        "model_url": "https://huggingface.co/ckpt/knollingcase/resolve/main/knollingcase.ckpt",
        "model_file": "knollingcase.ckpt"
    },
    "Liberty": {
        "model_url": "'https://civitai.com/api/download/models/6908?type=Model&format=SafeTensor'",
        "model_file": "liberty_main.safetensors"
    },
    "Lucky Strike Mix Realistic v0.2": {
        "model_url": "https://huggingface.co/ckpt/lucky-strike-mix/resolve/main/luckyStrikeMix_V02Realistic.safetensors",
        "model_file": "luckyStrikeMix_V02Realistic.safetensors"
    },
    "Lyriel v1.5": {
        "model_url": "https://huggingface.co/ckpt/lyriel/resolve/main/lyriel_v15.safetensors",
        "model_file": "lyriel_v15.safetensors"
    },
    "MCQ Ani v1.0": {
        "model_url": "https://huggingface.co/ckpt/mcq-ani/resolve/main/mcqAni_v10.safetensors",
        "model_file": "mcqAni_v10.safetensors"
    },
    "MCQ v1.0": {
        "model_url": "https://huggingface.co/ckpt/mcq/resolve/main/mcq_v10.safetensors",
        "model_file": "mcq_v10.safetensors"
    },
    "Magical Mix v1.0": {
        "model_url": "https://huggingface.co/ckpt/MagicalMix_v1/resolve/main/MagicalMix_v1.safetensors",
        "model_file": "MagicalMix_v1.safetensors",
        "vae": "kl_f8_anime2"
    },
    "Magical Mix v2.0": {
        "model_url": "https://huggingface.co/mekabu/MagicalMix_v2/resolve/main/MagicalMix_v2.safetensors",
        "model_file": "MagicalMix_v2.safetensors",
        "vae": "kl_f8_anime2"
    },
    "Maple Syrup v1.0": {
        "model_url": "https://huggingface.co/ckpt/maplesyrup/resolve/main/maplesyrup_v10.safetensor",
        "model_file": "maplesyrup_v10.safetensor"
    },
    "Mare Coloris": {
        "model_url": "https://huggingface.co/ckpt/MareColoris/resolve/main/MareColoris.safetensors",
        "model_file": "MareColoris.safetensors"
    },
    "Meina Mix v8.0 (baked vae)": {
        "model_url": "https://huggingface.co/ckpt/MeinaMix/resolve/main/Meina_V8_baked_VAE.safetensors",
        "model_file": "meinamix_meinaV8.safetensors"
    },
    "Midjourney v4.0": {
        "model_url": "https://huggingface.co/ckpt/midjourney-v4-diffusion/resolve/main/mdjrny-v4.ckpt",
        "model_file": "mdjrny-v4.ckpt"
    },
    "Mistoon Anime v1.0": {
        "model_url": "https://huggingface.co/ckpt/mistoonanime/resolve/main/mistoonAnime_v10.safetensors",
        "model_file": "mistoonAnime_v10.safetensors",
        "vae": "grapefruit"
    },
    "Mix Pro v4.0": {
        "model_url": "https://huggingface.co/ckpt/mix-pro/resolve/main/mixProV4_v4.safetensors",
        "model_file": "mixProV4_v4.safetensors"
    },
    "Mo Di Diffusion v1.0 (Pruned)": {
        "model_url": "https://huggingface.co/ckpt/mo-di-diffusion/resolve/main/moDi-v1-pruned.ckpt",
        "model_file": "moDi-v1-pruned.ckpt"
    },
    "Monstermash 4 + Anything v3.0": {
        "model_url": "https://huggingface.co/ckpt/monstermash_anyv3/resolve/main/monstermash4%2Banyv3.safetensors",
        "model_file": "monstermash4%2Banyv3.safetensors",
        "vae": "anything_v3"
    },
    "Monstermash 6 + Anything v3.0": {
        "model_url": "https://huggingface.co/ckpt/monstermash_anyv3/resolve/main/monstermash6%2Banyv3.safetensors",
        "model_file": "monstermash6%2Banyv3.safetensors",
        "vae": "anything_v3"
    },
    "Mousey Mix": {
        "model_url": "https://huggingface.co/closertodeath/mouseymix/resolve/main/mouseymix.safetensors",
        "model_file": "mouseymix.safetensors"
    },
    "Needyou Alpha 2": {
        "model_url": "https://huggingface.co/ckpt/needyou/resolve/main/needyou_alpha2.safetensors",
        "model_file": "needyou_alpha2.safetensors"
    },
    "Neverending Dream (baked vae)": {
        "model_url": "https://huggingface.co/Lykon/NeverEnding-Dream/resolve/main/NeverEndingDream_ft_mse.safetensors",
        "model_file": "neverending_dream_bakedvae.safetensors"
    },
    "Nostalgia Clear": {
        "model_url": "https://huggingface.co/ckpt/nostalgia-clear/resolve/main/nostalgiaClear_nostalgiaClear.safetensors",
        "model_file": "nostalgiaClear_nostalgiaClear.safetensors"
    },
    "Open Anime Journey": {
        "model_url": "https://huggingface.co/ckpt/OpenAnimeJourney/resolve/main/OpenAnimeJourney.ckpt",
        "model_file": "OpenAnimeJourney.ckpt",
        "vae": "anything_v3"
    },
    "Open Journey v2.0": {
        "model_url": "https://huggingface.co/ckpt/openjourney-v2/resolve/main/openjourney-v2.ckpt",
        "model_file": "openjourney-v2.ckpt"
    },
    "Open Journey v4.0": {
        "model_url": "https://huggingface.co/prompthero/openjourney-v4/resolve/main/openjourney-v4.ckpt",
        "model_file": "openjourney-v4.ckpt"
    },
    "Orange Cocoa Mix 2 HARD": {
        "model_url": "https://huggingface.co/ckpt/OrangeCocoaMix/resolve/main/OrangeCocoaMix2_hard.safetensors",
        "model_file": "OrangeCocoaMix2_hard.safetensors",
        "vae": "anything_v3"
    },
    "PVC v3.0 (fp32)": {
        "model_url": "https://huggingface.co/p1atdev/pvc-v3/resolve/checkpoints/pvc-v3-fp32.safetensors",
        "model_file": "pvc-v3-fp32.safetensors",
        "vae": "kl_f8_anime2"
    },
    "Padoru v1.0": {
        "model_url": "https://civitai.com/api/download/models/1522",
        "model_file": "padoruDiffusion_v1.ckpt"
    },
    "Papercut Diffusion v1.0": {
        "model_url": "https://huggingface.co/ckpt/Stable_Diffusion_PaperCut_Model/resolve/main/PaperCut_v1.ckpt",
        "model_file": "PaperCut_v1.ckpt"
    },
    "Pastel Boys 2D v2.0": {
        "model_url": "https://huggingface.co/ckpt/pastelboys2d/resolve/main/pastelboys2D_v20.safetensors",
        "model_file": "pastelboys2D_v20.safetensors"
    },
    "Pastel Mix Stylized Anime (fp16)": {
        "model_url": "https://huggingface.co/andite/pastel-mix/resolve/main/pastelmix-fp16.ckpt",
        "model_file": "pastelmix-fp16.ckpt",
        "vae": "kl_f8_anime2"
    },
    "Pastel Mix Stylized Anime (fp32)": {
        "model_url": "https://huggingface.co/andite/pastel-mix/resolve/main/pastelmix-fp32.ckpt",
        "model_file": "pastelmix-fp32.ckpt",
        "vae": "kl_f8_anime2"
    },
    "Pegasus 9 Mix v1.0": {
        "model_url": "https://huggingface.co/ckpt/pegasus-9-mix/resolve/main/pegasus9Mix_pegasus9MixV10.safetensors",
        "model_file": "pegasus9Mix_pegasus9MixV10.safetensors"
    },
    "Perfect World v2 (baked vae)": {
        "model_url": "https://huggingface.co/ckpt/perfect_world/resolve/main/perfectWorld_v2Baked.safetensors",
        "model_file": "perfectWorld_v2Baked.safetensors"
    },
    "Photorealostic Fuen v1.0": {
        "model_url": "https://huggingface.co/ckpt/photorealistic-fuen-v1/resolve/main/photorealistic-fuen-v1.ckpt",
        "model_file": "photorealistic-fuen-v1.ckpt"
    },
    "Pony Diffusion v2.0": {
        "model_url": "https://huggingface.co/ckpt/pony-diffusion-v2/resolve/main/pony-diffusion-v2.ckpt",
        "model_file": "pony-diffusion-v2.ckpt"
    },
    "Pony Diffusion v3.0": {
        "model_url": "https://huggingface.co/ckpt/pony-diffusion-v3/resolve/main/pony-diffusion-v3.ckpt",
        "model_file": "pony-diffusion-v3.ckpt"
    },
    "Pony Diffusion v4.0": {
        "model_url": "https://huggingface.co/ckpt/pony-diffusion-v4/resolve/main/pony-diffusion-v4.ckpt",
        "model_file": "pony-diffusion-v4.ckpt"
    },
    "Popup Book Diffusion v1.0": {
        "model_url": "https://huggingface.co/ckpt/popupBook-diffusion/resolve/main/popupBook-diffusion-v1.ckpt",
        "model_file": "popupBook-diffusion-v1.ckpt"
    },
    "Protogen Nova": {
        "model_url": "https://huggingface.co/ckpt/Protogen_Nova_Official_Release/resolve/main/Protogen_Nova_Official_Release.ckpt",
        "model_file": "Protogen_Nova_Official_Release.ckpt",
        "yaml_url": "https://huggingface.co/ckpt/Protogen_Nova_Official_Release/raw/main/Protogen_Nova_Official_Release.yaml",
        "yaml_file": "Protogen_Nova_Official_Release.yaml"
    },
    "Protogen X v3.4": {
        "model_url": "https://huggingface.co/darkstorm2150/Protogen_x3.4_Official_Release/resolve/main/ProtoGen_X3.4.safetensors",
        "model_file": "Protogen_X3.4.safetensors"
    },
    "Protogen v2.2": {
        "model_url": "https://huggingface.co/ckpt/Protogen_V2.2/resolve/main/Protogen_V2.2.ckpt",
        "model_file": "Protogen_V2.2.ckpt"
    },
    "RPG v4.0": {
        "model_url": "https://huggingface.co/Anashel/rpg/resolve/main/RPG-V4-Model-Download/RPG-v4.safetensors",
        "model_file": "RPG-v4.safetensors",
        "yaml_url": "https://huggingface.co/Anashel/rpg/raw/main/RPG-V4-Model-Download/RPG-v4.yaml",
        "yaml_file": "RPG-v4.yaml"
    },
    "Rando mix 3": {
        "model_url": "https://huggingface.co/ckpt/RandoMix3/resolve/main/RandoMix3.ckpt",
        "model_file": "RandoMix3.ckpt",
        "vae": "randomix_3"
    },
    "Realbiter v1.0": {
        "model_url": "https://huggingface.co/ckpt/RealBiter/resolve/main/realbiter_v10.safetensors",
        "model_file": "realbiter_v10.safetensors"
    },
    "Realistic Experience": {
        "model_url": "https://huggingface.co/Schisim/Experience/resolve/main/Realistic_EXP.safetensors",
        "model_file": "Realistic_EXP.safetensors"
    },
    "Realistic Vision v1.3": {
        "model_url": "'https://civitai.com/api/download/models/6987?type=Model&format=SafeTensor'",
        "model_file": "realisticVisionV13_v13.safetensors"
    },
    "Realistic Vision v2.0": {
        "model_url": "https://huggingface.co/ckpt/realistic-vision-v20/resolve/main/realisticVisionV20_v20.safetensors",
        "model_file": "realisticVisionV20_v20.safetensors"
    },
    "RefSlave v2.0": {
        "model_url": "https://huggingface.co/ckpt/bucket/resolve/main/refslaveV2_v2-emaonly.safetensors",
        "model_file": "RefSlave-V2.safetensors",
        "vae": "refslave"
    },
    "Replicant v2.0": {
        "model_url": "https://huggingface.co/ckpt/replicant-v20/resolve/main/replicantV20_v20.safetensors",
        "model_file": "replicantV20_v20.safetensors"
    },
    "Rev Animated v1.1": {
        "model_url": "https://huggingface.co/ckpt/rev-animated/resolve/main/revAnimated_v11.safetensors",
        "model_file": "revAnimated_v11.safetensors"
    },
    "Rev Animated v1.2.1": {
        "model_url": "https://huggingface.co/ckpt/rev-animated/resolve/main/revAnimated_v121.safetensors",
        "model_file": "revAnimated_v121.safetensors"
    },
    "Riffusion v1.0": {
        "model_url": "https://huggingface.co/ckpt/riffusion-model-v1/resolve/main/riffusion-model-v1.ckpt",
        "model_file": "riffusion-model-v1.ckpt"
    },
    "Rmada Merge v5.0": {
        "model_url": "https://huggingface.co/ckpt/rmada-merge-sd-21-768/resolve/main/rmadaMergeSD21768_v50.safetensors",
        "model_file": "rmadaMergeSD21768_v50.safetensors",
        "yaml_url": "https://huggingface.co/ckpt/rmada-merge-sd-21-768/raw/main/rmadaMergeSD21768_v50.yaml",
        "yaml_file": "rmadaMergeSD21768_v50.yaml",
        "embeds_lists": {
            "embeds_urls": [
                "https://huggingface.co/ckpt/bucket/resolve/main/embed/nartfixer.pt",
                "https://huggingface.co/ckpt/bucket/resolve/main/embed/nfixer.pt",
                "https://huggingface.co/ckpt/bucket/resolve/main/embed/nrealfixer.pt"
            ],
            "embeds_files": [
                "nartfixer.pt",
                "nfixer.pt",
                "nrealfixer.pt"
            ]
        }
    },
    "Rmadart v5.0": {
        "model_url": "https://huggingface.co/ckpt/rmadart-sd15/resolve/main/rmadartSD15_50.safetensors",
        "model_file": "rmadartSD15_50.safetensors.safetensors"
    },
    "Robo Diffusion v1.0": {
        "model_url": "https://huggingface.co/ckpt/robo-diffusion/resolve/main/roboDiffusion_v1.ckpt",
        "model_file": "roboDiffusion_v1.ckpt"
    },
    "SamDoesArt v3.0": {
        "model_url": "https://huggingface.co/ckpt/SamDoesArt-V3/resolve/main/SamDoesArt-V3.ckpt",
        "model_file": "SamDoesArt-V3.ckpt"
    },
    "SamDoesSexy Blend": {
        "model_url": "https://huggingface.co/ckpt/samdoessexy-blend/resolve/main/samdoessexyBlend.safetensors",
        "model_file": "samdoessexyBlend.safetensors"
    },
    "Seek Art Mega v1.0": {
        "model_url": "https://huggingface.co/ckpt/seek.art_MEGA/resolve/main/seek_art_mega_v1.ckpt",
        "model_file": "seek_art_mega_v1.ckpt"
    },
    "Seek Art Mega v2.0": {
        "model_url": "https://huggingface.co/ckpt/seekart-mega/resolve/main/seekArtMEGA_mega20.safetensors",
        "model_file": "seekArtMEGA_mega20.safetensors"
    },
    "Simpmaker 3k": {
        "model_url": "https://huggingface.co/ckpt/SimpMaker-3K1/resolve/main/SimpMaker%203k.ckpt",
        "model_file": "SimpMaker%203k.ckpt"
    },
    "Something v2.0": {
        "model_url": "https://huggingface.co/ckpt/SomethingV2/resolve/main/somethingv2.safetensors",
        "model_file": "somethingv2.safetensors"
    },
    "Stable Diffusion v1.4": {
        "model_url": "https://huggingface.co/ckpt/sd14/resolve/main/sd-v1-4.ckpt",
        "model_file": "sd-v1-4.ckpt"
    },
    "Stable Diffusion v1.5 (Pruned) (EMA Only)": {
        "model_url": "https://huggingface.co/ckpt/sd15/resolve/main/v1-5-pruned-emaonly.ckpt",
        "model_file": "v1-5-pruned-emaonly.ckpt"
    },
    "Stable Diffusion v1.5 Inpainting": {
        "model_url": "https://huggingface.co/ckpt/i15/resolve/main/sd-v1-5-inpainting.ckpt",
        "model_file": "sd-v1-5-inpainting.ckpt"
    },
    "Stable Diffusion v2.0 (EMA Only)": {
        "model_url": "https://huggingface.co/ckpt/stable-diffusion-2/resolve/main/768-v-ema.ckpt",
        "model_file": "768-v-ema.ckpt",
        "yaml_url": "https://huggingface.co/ckpt/stable-diffusion-2/raw/main/v2-inference-v.yaml",
        "yaml_file": "768-v-ema.yaml"
    },
    "Stable Diffusion v2.0 Base (EMA Only)": {
        "model_url": "https://huggingface.co/ckpt/stable-diffusion-2-base/resolve/main/512-base-ema.ckpt",
        "model_file": "512-base-ema.ckpt",
        "yaml_url": "https://huggingface.co/ckpt/stable-diffusion-2-base/raw/main/v2-inference.yaml",
        "yaml_file": "512-base-ema.yaml"
    },
    "Stable Diffusion v2.0 Depth (EMA Only)": {
        "model_url": "https://huggingface.co/ckpt/stable-diffusion-2-depth/resolve/main/512-depth-ema.ckpt",
        "model_file": "512-depth-ema.ckpt",
        "yaml_url": "https://huggingface.co/ckpt/stable-diffusion-2-depth/raw/main/v2-midas-inference.yaml",
        "yaml_file": "512-depth-ema.yaml",
        "embeds_lists": {
            "embeds_urls": [
                "https://huggingface.co/spaablauw/FloralMarble/resolve/main/FloralMarble-400.pt"
            ],
            "embeds_files": [
                "FloralMarble-400.pt"
            ]
        }
    },
    "Stable Diffusion v2.0 Inpainting (EMA Only)": {
        "model_url": "https://huggingface.co/ckpt/stable-diffusion-2-inpainting/resolve/main/512-inpainting-ema.ckpt",
        "model_file": "512-inpainting-ema.ckpt",
        "yaml_url": "https://huggingface.co/ckpt/stable-diffusion-2-inpainting/raw/main/v2-inpainting-inference.yaml",
        "yaml_file": "512-inpainting-ema.yaml"
    },
    "Stable Diffusion v2.1 (Pruned) (EMA Only)": {
        "model_url": "https://huggingface.co/ckpt/stable-diffusion-2-1/resolve/main/v2-1_768-ema-pruned.ckpt",
        "model_file": "v2-1_768-ema-pruned.ckpt",
        "yaml_url": "https://huggingface.co/ckpt/stable-diffusion-2-1/raw/main/v2-inference-v.yaml",
        "yaml_file": "v2-1_768-ema-pruned.yaml",
        "embeds_lists": {
            "embeds_urls": [
                "https://huggingface.co/joachimsallstrom/Double-Exposure-Embedding/resolve/main/dblx.pt",
                "https://huggingface.co/Conflictx/AnimeScreencap/resolve/main/AnimeScreenCap.pt"
            ],
            "embeds_files": [
                "dblx.pt",
                "AnimeScreenCap.pt"
            ]
        }
    },
    "Stable Diffusion v2.1 Base (Pruned) (EMA Only)": {
        "model_url": "https://huggingface.co/ckpt/stable-diffusion-2-1-base/resolve/main/v2-1_512-ema-pruned.ckpt",
        "model_file": "v2-1_512-ema-pruned.ckpt",
        "yaml_url": "https://huggingface.co/ckpt/stable-diffusion-2-1-base/raw/main/v2-inference.yaml",
        "yaml_file": "v2-1_512-ema-pruned.yaml"
    },
    "Stablydiffuseds Aesthetic Mix v2.6": {
        "model_url": "'https://civitai.com/api/download/models/6266?type=Pruned%20Model&format=SafeTensor'",
        "model_file": "stablydiffuseds_26.safetensors"
    },
    "Starlike v1.0": {
        "model_url": "https://huggingface.co/ckpt/starlike/resolve/main/starlike_v10.safetensors",
        "model_file": "starlike_v10.safetensors"
    },
    "Sukiyaki Mix v1.0": {
        "model_url": "https://huggingface.co/Vsukiyaki/SukiyakiMix-v1.0/resolve/main/SukiyakiMix-v1.0-fp32.safetensors",
        "model_file": "SukiyakiMix-v1.0"
    },
    "Synthwave Punk v2.0": {
        "model_url": "https://huggingface.co/ckpt/SynthwavePunk-v2/resolve/main/SynthwavePunk-v2.ckpt",
        "model_file": "SynthwavePunk-v2.ckpt"
    },
    "TMND Mix Plus": {
        "model_url": "https://huggingface.co/ckpt/tmnd-mix/resolve/main/tmndMix_tmndMixPlus.safetensors",
        "model_file": "tmndMix_tmndMixPlus.safetensors"
    },
    "Toonyou Alpha 3": {
        "model_url": "https://huggingface.co/ckpt/toonyou/resolve/main/toonyou_alpha3.safetensors",
        "model_file": "toonyou_alpha3.safetensors"
    },
    "Uber Realistic Porn Maker v1.0 (EMA Only)": {
        "model_url": "https://huggingface.co/ckpt/urp/resolve/main/uberRealisticPornMer_urpMv1_ema.ckpt",
        "model_file": "uberRealisticPornMer_urpMv1_ema.ckpt"
    },
    "Uber Realistic Porn Merge v1.3": {
        "model_url": "https://huggingface.co/ckpt/urpm/resolve/main/uberRealisticPornMerge_urpmv13.safetensors",
        "model_file": "uberRealisticPornMerge_urpmv13.safetensors"
    },
    "Van Gogh Diffusion": {
        "model_url": "https://huggingface.co/ckpt/Van-Gogh-diffusion/resolve/main/Van-Gogh-Style-lvngvncnt-v2.ckpt",
        "model_file": "Van-Gogh-Style-lvngvncnt-v2.ckpt"
    },
    "Vinte Protogen Mix v1.0": {
        "model_url": "https://civitai.com/api/download/models/6582",
        "model_file": "vinteprotogenmix_v10.safetensors"
    },
    "Vintedois Diffusion v0.1": {
        "model_url": "https://huggingface.co/ckpt/vintedois-diffusion-v0-1/resolve/main/vintedois_0_1.ckpt",
        "model_file": "vintedois_0_1.ckpt"
    },
    "Voxo v0.0": {
        "model_url": "https://huggingface.co/junjuice0/VOXO/resolve/main/VOXO-v0.ckpt",
        "model_file": "VOXO-v0.ckpt"
    },
    "Waifu Diffusion v1.3 (fp32)": {
        "model_url": "https://huggingface.co/ckpt/waifu-diffusion-v1-3/resolve/main/wd-v1-3-float32.ckpt",
        "model_file": "wd-v1-3-float32.ckpt",
        "vae": "kl_f8_anime2"
    },
    "Waifu Diffusion v1.4-anime-e1": {
        "model_url": "https://huggingface.co/ckpt/waifu-diffusion-v1-4/resolve/main/wd-1-4-anime_e1.ckpt",
        "model_file": "wd-1-4-anime_e1.ckpt",
        "yaml_url": "https://huggingface.co/ckpt/waifu-diffusion-v1-4/raw/main/wd-1-4-anime_e1.yaml",
        "yaml_file": "wd-1-4-anime_e1.yaml",
        "vae": "kl_f8_anime2"
    },
    "Waifu Diffusion v1.5 beta 1 (fp32)": {
        "model_url": "https://huggingface.co/ckpt/wd-1-5-beta/resolve/main/wd15-beta1-fp32.safetensors",
        "model_file": "wd15-beta1-fp32.safetensors",
        "yaml_url": "https://huggingface.co/ckpt/wd-1-5-beta/raw/main/wd15-beta1-fp32.yaml",
        "yaml_file": "wd15-beta1-fp32.yaml",
        "vae": "kl_f8_anime2"
    },
    "Waifu Diffusion v1.5 beta 2 (fp32)": {
        "model_url": "https://huggingface.co/waifu-diffusion/wd-1-5-beta2/resolve/main/checkpoints/wd-1-5-beta2-fp32.safetensors",
        "model_file": "wd-1-5-beta2-fp32.safetensors",
        "yaml_url": "https://huggingface.co/waifu-diffusion/wd-1-5-beta2/raw/main/checkpoints/wd-1-5-beta2-fp32.yaml",
        "yaml_file": "wd-1-5-beta2-fp32.yaml",
        "vae": "kl_f8_anime2"
    },
    "Waifu Diffusion v1.5 beta 2 Aesthetic (fp32)": {
        "model_url": "https://huggingface.co/waifu-diffusion/wd-1-5-beta2/resolve/main/checkpoints/wd-1-5-beta2-aesthetic-fp32.safetensors",
        "model_file": "wd-1-5-beta2-aesthetic-fp32.safetensors",
        "yaml_url": "https://huggingface.co/waifu-diffusion/wd-1-5-beta2/raw/main/checkpoints/wd-1-5-beta2-aesthetic-fp32.yaml",
        "yaml_file": "wd-1-5-beta2-aesthetic-fp32.yaml",
        "vae": "kl_f8_anime2"
    },
    "Woolitize": {
        "model_url": "https://huggingface.co/ckpt/woolitize/resolve/main/woolitize.ckpt",
        "model_file": "woolitize.ckpt"
    },
    "Xrikishi's Unstable Alpha 6": {
        "model_url": "https://huggingface.co/xRikishi/xRikishi/resolve/main/xRikishi_Unstable_Diffusion_Alpha_6_0.safetensors",
        "model_file": "xrikishisUnstable_alpha60.safetensors"
    },
    "Yiffy E18": {
        "model_url": "https://huggingface.co/ckpt/yiffy-e18/resolve/main/yiffy-e18.ckpt",
        "model_file": "yiffy-e18.ckpt"
    },
    "Yiffy Mix": {
        "url1": "https://huggingface.co/ckpt/yiffymix/resolve/main/yiffymix.safetensors",
        "file1": "yiffymix.safetensors",
        "vae": "kl_f8_anime2"
    },
    "Yohan Diffusion": {
        "model_url": "https://huggingface.co/ckpt/yohan-diffusion/resolve/main/yohan-diffusion.ckpt",
        "model_file": "yohan-diffusion.ckpt",
        "vae": "anything_v3"
    }
}

# Negative Embeddings dictionnary

neg_embeds_dict = {
    "bad_artist": {
        "embed_url": "https://huggingface.co/embed/negative/resolve/main/bad-artist.pt",
        "embed_file": "bad-artist.pt",
        "value": bad_artist
    },
    "bad_artist_anime": {
        "embed_url": "https://huggingface.co/embed/negative/resolve/main/bad-artist-anime.pt",
        "embed_file": "bad-artist-anime.pt",
        "value": bad_artist_anime
    },
    "bad_hands_5": {
        "embed_url": "https://huggingface.co/embed/negative/resolve/main/bad-hands-5.pt",
        "embed_file": "bad-hands-5.pt",
        "value": bad_hands_5
    },
    "bad_prompt": {
        "embed_url": "https://huggingface.co/datasets/Nerfgun3/bad_prompt/resolve/main/bad_prompt.pt",
        "embed_file": "bad_prompt.pt",
        "value": bad_prompt
    },
    "bad_prompt_version2": {
        "embed_url": "https://huggingface.co/embed/negative/resolve/main/bad_prompt_version2.pt",
        "embed_file": "bad_prompt_version2.pt",
        "value": bad_prompt_version2
    },
    "easynegative": {
        "embed_url": "https://huggingface.co/embed/negative/resolve/main/EasyNegative.pt",
        "embed_file": "EasyNegative.pt",
        "value": easynegative
    },
    "ng_deepnegative_v1_75t": {
        "embed_url": "https://huggingface.co/embed/negative/resolve/main/ng_deepnegative_v1_75t.pt",
        "embed_file": "ng_deepnegative_v1_75t.pt",
        "value": ng_deepnegative_v1_75t
    },
    "unspeakable_horrors_64": {
        "embed_url": "https://civitai.com/api/download/models/5103",
        "embed_file": "Unspeakable-Horrors-64v.pt",
        "value": unspeakable_horrors_64
    },
    "bad_image_v2_39000": {
        "embed_url": "https://huggingface.co/embed/negative/resolve/main/bad-image-v2-39000.pt",
        "embed_file": "bad-image-v2-39000.pt",
        "value": bad_image_v2_39000
    }
}

# Positive LoRA dictionnary

pos_loras_dict = {
    "epiNoiseoffset_v2": {
        "lora_url": "https://huggingface.co/embed/lora/resolve/main/epiNoiseoffset_v2.safetensors",
        "lora_file": "epiNoiseoffset_v2.safetensors",
        "value": epi_noise_offset_v2
    },
    "animeLineartMangaLike_v30MangaLike": {
        "lora_url": "https://huggingface.co/embed/lora/resolve/main/animeLineartMangaLike_v30MangaLike.safetensors",
        "lora_file": "animeLineartMangaLike_v30MangaLike.safetensors",
        "value": animeLineartMangaLike_v30MangaLike
    }

}
# VAEs dictionnary

vaes_dict = {
    "anything_v3": {
        "vae_url": "https://huggingface.co/ckpt/anything-v3.0/resolve/main/Anything-V3.0.vae.pt",
        "vae_file": "Anything-V3.0.vae.pt",
        "value": anything_v3
    },
    "anything_v4": {
        "vae_url": "https://huggingface.co/ckpt/anything-v4.0/resolve/main/anything-v4.0.vae.pt",
        "vae_file": "anything-v4.0.vae.pt",
        "value": anything_v4
    },
    "grapefruit": {
        "vae_url": "https://huggingface.co/ckpt/grapefruit/resolve/main/grapefruit.vae.pt",
        "vae_file": "grapefruit.vae.pt",
        "value": grapefruit
    },
    "kl_f8_anime2": {
        "vae_url": "https://huggingface.co/hakurei/waifu-diffusion-v1-4/resolve/main/vae/kl-f8-anime2.ckpt",
        "vae_file": "kl-f8-anime2.ckpt",
        "value": kl_f8_anime2
    },
    "orangemix": {
        "vae_url": "https://huggingface.co/ckpt/OrangeMixs/resolve/main/orangemix.vae.pt",
        "vae_file": "orangemix.vae.pt",
        "value": orangemix
    },
    "randomix_3": {
        "vae_url": "https://huggingface.co/ckpt/RandoMix3/resolve/main/RandoMix3.vae.pt",
        "vae_file": "RandoMix3.vae.pt",
        "value": randomix_3
    },
    "refslave": {
        "vae_url": "https://huggingface.co/ckpt/bucket/resolve/main/RefSlave-vae.pt",
        "vae_file": "RefSlave-vae.pt",
        "value": refslave
    }
}

# Upscalers dictionnary

upscalers_dict = {
    "_4x_ultra_sharp": {
        "upscaler_url": "https://huggingface.co/embed/upscale/resolve/main/4x-UltraSharp.pth",
        "upscaler_file": "4x-UltraSharp.pth",
        "value": _4x_ultra_sharp
    }
}
# Tunnels dictionnary

tunnels = {
    "Cloudflare": "--cloudflared",
    "Gradio": "",
    "Remote.moe": "--remotemoe"
}

################
##### CODE #####
################

# Installing requirements
print("Moving to:")
# %cd /content
print("Hiding warning about TensorRT:")
# %env TF_CPP_MIN_LOG_LEVEL=1
print("Installing aria2...")
# !apt-get -y install aria2 libcairo2-dev pkg-config python3-dev > /dev/null
print("Installing Torch 2.0 and dependencies")
# !pip install -q torch==2.0.0+cu118 torchvision==0.15.1+cu118 torchaudio==2.0.1+cu118 torchtext==0.15.1 torchdata==0.6.0 --extra-index-url https://download.pytorch.org/whl/cu118 -U
print("Installing xformers 0.0.19 and triton 2")
# !pip install -q xformers==0.0.19 triton==2.0.0 -U

# Daviljoe193 ram management fix

print("Setting up Daviljoe193's fix for colab's ram management...")
# !aria2c $aria_args http://launchpadlibrarian.net/367274644/libgoogle-perftools-dev_2.5-2.2ubuntu3_amd64.deb
# !aria2c $aria_args https://launchpad.net/ubuntu/+source/google-perftools/2.5-2.2ubuntu3/+build/14795286/+files/google-perftools_2.5-2.2ubuntu3_all.deb
# !aria2c $aria_args https://launchpad.net/ubuntu/+source/google-perftools/2.5-2.2ubuntu3/+build/14795286/+files/libtcmalloc-minimal4_2.5-2.2ubuntu3_amd64.deb
# !aria2c $aria_args https://launchpad.net/ubuntu/+source/google-perftools/2.5-2.2ubuntu3/+build/14795286/+files/libgoogle-perftools4_2.5-2.2ubuntu3_amd64.deb
# !apt -y install libunwind8-dev > /dev/null 2>&1
# !dpkg -i *.deb > /dev/null 2>&1
# %env LD_PRELOAD=libtcmalloc.so
# !rm *.deb

# Downloading main Stable Diffusion repository

print("Downloading Camenduru's " + bypass + " repository from v2.2 branch")
# !git clone -q -b v2.2 https://github.com/camenduru/{bypass}
print("Downloading Tunnels extension")
# !git clone -q https://github.com/camenduru/sd-webui-tunnels /content/{bypass}/extensions/sd-webui-tunnels
print("Downloading StealthPNG extension")
# !git clone -q https://github.com/camenduru/sd_webui_stealth_pnginfo /content/{bypass}/extensions/sd_webui_stealth_pnginfo
print("Downloading default VAE")
# !aria2c $aria_args https://huggingface.co/stabilityai/sd-vae-ft-mse-original/resolve/main/vae-ft-mse-840000-ema-pruned.safetensors -d {vaes_folder} -o vae-ft-mse-840000-ema-pruned.safetensors

# Downloading requested extensions' repositories and models

for name, data in repos_dict.items():
    if data["value"]:
        clone_path = f"{root_folder}/{data['subfolder']}/{name}"
        aria2_path = f"{root_folder}/{data['subfolder']}"
        if data["command"] == "clone":
            print(f"Downloading extension : {name}")
            # !git clone -q -b {data["branch"]} {data["repo"]} {clone_path}
        elif data["command"] == "aria2":
            print(f"Downloading extension model or file : {name}")
            # !aria2c $aria_args {data["repo"]} -d {aria2_path} -o {name}

# Downloading models for ControlNet

if controlnet_v1_1:
    for ctrlnet_model in ctrlnet_list:
        print(f"Downloading ControlNet model : {ctrlnet_model}")
        # !aria2c $aria_args {ctrlnet_url}/{ctrlnet_model} -d {ctrlnet_folder} -o {ctrlnet_model}
    for ctrlnet_yaml in ctrlnet_yaml_list:
        print(f"Downloading ControlNet config : {ctrlnet_yaml}")
        # !aria2c $aria_args {ctrlnet_yaml_url}/{ctrlnet_yaml} -d {ctrlnet_folder} -o {ctrlnet_yaml}

# Downloading selected model

if Model in models_dict:
    model_url = models_dict[Model]["model_url"]
    model_file = models_dict[Model]["model_file"]
    print(f"Downloading Stable Diffusion model file : {model_file}")
    # !aria2c $aria_args {model_url} -d {models_folder} -o {model_file}
    ckpt_arg = f"{models_folder}/{model_file}"
    if "yaml_url" in models_dict[Model]:
        yaml_url = models_dict[Model]["yaml_url"]
        yaml_file = models_dict[Model]["yaml_file"]
        print(f"Downloading {Model} yaml file : {yaml_file}")
        # !aria2c $aria_args {yaml_url} -d {models_folder} -o {yaml_file}
    if "embeds_lists" in models_dict[Model]:
        embeds_urls = models_dict[Model]["embeds_lists"]["embeds_urls"]
        embeds_files = models_dict[Model]["embeds_lists"]["embeds_files"]
        for i, embed_url in enumerate(embeds_urls):
            embed_file = embeds_files[i]
            print(f"Downloading {Model} embedding (textual inversion) {i+1}: {embed_file}")
            # !aria2c $aria_args {embed_url} -d {embeds_folder} -o {embed_file}
    if "vae" in models_dict[Model]:
        vae_name = models_dict[Model]["vae"]
        if vaes_dict[vae_name]["value"] == False:
            vaes_dict[vae_name]["value"] = True
        print(f"VAE {vae_name} will be downloaded as recommended by this model.")
    if Model == "Stable diffusion 2 Depth":
        print("Adding 'name = list(data.keys())[0]' to 'textual_inversion.py'")
        # !sed -i -e '/emb = emb.unsqueeze(0)/a\                name = list(data.keys())[0]' {root_folder}/modules/textual_inversion/textual_inversion.py
    if Model == "Riffusion v1":
        print("Downloading extension : sd-webui-riffusion")
        # !git clone -q https://github.com/enlyth/sd-webui-riffusion /content//extensions/sd-webui-riffusion
        print("Deleting install.py and requirements.txt from the extension folder")
        # !rm {root_folder}/extensions/sd-webui-riffusion/install.py {root_folder}/extensions/sd-webui-riffusion/requirements.txt
        print("Installing package pedalboard")
        # !pip -q install pedalboard

# Downloading selected negative embeddings

for embed_name, embed_info in neg_embeds_dict.items():
    if embed_info["value"]:
        embed_url = embed_info["embed_url"]
        embed_file = embed_info["embed_file"]
        print(f"Downloading embedding (textual inversion): {embed_file}")
        # !aria2c $aria_args {embed_url} -d {neg_embeds_folder} -o {embed_file}

# Downloading selected positive LoRAs

for lora_name, lora_info in pos_loras_dict.items():
    if lora_info["value"]:
        lora_url = lora_info["lora_url"]
        lora_file = lora_info["lora_file"]
        print(f"Downloading LoRA: {lora_file}")
        if additional_networks:
            # !aria2c $aria_args {lora_url} -d {pos_loras_addnet_folder} -o {lora_file}
        else:
            # !aria2c $aria_args {lora_url} -d {pos_loras_folder} -o {lora_file}

# Downloading selected VAEs

for vae_name, vae_info in vaes_dict.items():
    if vae_info["value"]:
        vae_url = vae_info["vae_url"]
        vae_file = vae_info["vae_file"]
        print(f"Downloading VAE: {vae_file}")
        # !aria2c $aria_args {vae_url} -d {vaes_folder} -o {vae_file}

# Downloading selected upscalers

for ups_name, ups_info in upscalers_dict.items():
    if ups_info["value"]:
        ups_url = ups_info["upscaler_url"]
        ups_file = ups_info["upscaler_file"]
        print(f"Downloading upscaler: {ups_file}")
        # !aria2c $aria_args {ups_url} -d {upscalers_folder} -o {ups_file}

# Adding tunnel argument (DEPRECATED)

#for tunnel_key, tunnel_value in tunnels.items():
#    if tunnel == tunnel_key:
#        host = tunnel_value

# Setting dark theme on/off

if dark_theme:
    dark = "--theme dark"

####################
##### HOTFIXES #####
####################

print("Hotfixes (if any):")

## ControlNet/Deforum "folder not found"

if deforum and controlnet_v1_1:
    print("Fixing Deforum x ControlNet 'folder not found' error")
    # !mkdir {root_folder}/extensions/deforum-for-automatic1111-webui/models

# Changing a dictionnary from ram to vram

print("Fixing some memory management")
# !sed -i -e '''/    prepare_environment()/a\    os.system\(f\"""sed -i -e ''\"s/dict()))/dict())).cuda()/g\"'' /content/{bypass}/repositories/stable-diffusion-stability-ai/ldm/util.py""")''' /content/{bypass}/launch.py

###########################
##### LAUNCHING WEBUI #####
###########################

print("Moving to :")
# %cd $root_folder

## QoL improvements

print("QoL improvements (if any):")
print("Adding vae list and clipskip slider near models list in webui")
# !sed -i -e 's/\"sd_model_checkpoint\"\,/\"sd_model_checkpoint\,sd_vae\,CLIP_stop_at_last_layers\"\,/g' /content/{bypass}/modules/shared.py

## Finale

print("Running launch.py. From there, it's webui's code.")
# !python launch.py --xformers --enable-insecure-extension-access --gradio-queue --multiple $dark --ckpt $ckpt_arg --vae-path $vaes_folder/vae-ft-mse-840000-ema-pruned.safetensors
# Out:
# Moving to:
# /content
# Hiding warning about TensorRT:
# env: TF_CPP_MIN_LOG_LEVEL=1
# Installing aria2...
# Installing Torch 2.0 and dependencies
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.3/2.3 GB 871.1 kB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.1/6.1 MB 107.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.4/4.4 MB 107.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.0/2.0 MB 92.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.6/4.6 MB 119.1 MB/s eta 0:00:00
# Installing xformers 0.0.19 and triton 2
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 108.2/108.2 MB 10.0 MB/s eta 0:00:00
# Setting up Daviljoe193's fix for colab's ram management...
# env: LD_PRELOAD=libtcmalloc.so
# Downloading Camenduru's stable-diffusion-webui repository from v2.2 branch
# Downloading Tunnels extension
# Downloading StealthPNG extension
# Downloading default VAE
# Downloading extension : a1111-sd-webui-locon
# Downloading extension : a1111-sd-webui-lycoris
# Downloading extension : batchlinks-webui
# Downloading extension : deforum-for-automatic1111-webui
# Downloading extension model or file : instruct-pix2pix-00-22000.safetensors
# Downloading extension : openpose-editor
# Downloading extension : posex
# Downloading extension model or file : run_n_times.py
# Downloading extension : sd-civitai-browser
# Downloading extension : sd-webui-3d-open-pose-editor
# Downloading extension : sd-webui-additional-networks
# Downloading extension : sd-webui-controlnet
# Downloading extension : sd-webui-depth-lib
# Downloading extension : stable-diffusion-webui-catpuccin
# Downloading extension : stable-diffusion-webui-huggingface
# Downloading extension : stable-diffusion-webui-images-browser
# Downloading extension : stable-diffusion-webui-rembg
# Downloading extension : stable-diffusion-webui-two-shot
# Downloading ControlNet model : control_v11e_sd15_ip2p_fp16.safetensors
# Downloading ControlNet model : control_v11e_sd15_shuffle_fp16.safetensors
# Downloading ControlNet model : control_v11p_sd15_canny_fp16.safetensors
# Downloading ControlNet model : control_v11f1p_sd15_depth_fp16.safetensors
# Downloading ControlNet model : control_v11p_sd15_inpaint_fp16.safetensors
# Downloading ControlNet model : control_v11p_sd15_lineart_fp16.safetensors
# Downloading ControlNet model : control_v11p_sd15_mlsd_fp16.safetensors
# Downloading ControlNet model : control_v11p_sd15_normalbae_fp16.safetensors
# Downloading ControlNet model : control_v11p_sd15_openpose_fp16.safetensors
# Downloading ControlNet model : control_v11p_sd15_scribble_fp16.safetensors
# Downloading ControlNet model : control_v11p_sd15_seg_fp16.safetensors
# Downloading ControlNet model : control_v11p_sd15_softedge_fp16.safetensors
# Downloading ControlNet model : control_v11p_sd15s2_lineart_anime_fp16.safetensors
# Downloading ControlNet model : control_v11f1e_sd15_tile_fp16.safetensors
# Downloading ControlNet model : t2iadapter_style_sd14v1.pth
# Downloading ControlNet model : t2iadapter_sketch_sd14v1.pth
# Downloading ControlNet model : t2iadapter_seg_sd14v1.pth
# Downloading ControlNet model : t2iadapter_openpose_sd14v1.pth
# Downloading ControlNet model : t2iadapter_keypose_sd14v1.pth
# Downloading ControlNet model : t2iadapter_depth_sd14v1.pth
# Downloading ControlNet model : t2iadapter_color_sd14v1.pth
# Downloading ControlNet model : t2iadapter_canny_sd14v1.pth
# Downloading ControlNet model : t2iadapter_canny_sd15v2.pth
# Downloading ControlNet model : t2iadapter_depth_sd15v2.pth
# Downloading ControlNet model : t2iadapter_sketch_sd15v2.pth
# Downloading ControlNet model : t2iadapter_zoedepth_sd15v1.pth
# Downloading ControlNet config : control_v11e_sd15_ip2p_fp16.yaml
# Downloading ControlNet config : control_v11e_sd15_shuffle_fp16.yaml
# Downloading ControlNet config : control_v11p_sd15_canny_fp16.yaml
# Downloading ControlNet config : control_v11f1p_sd15_depth_fp16.yaml
# Downloading ControlNet config : control_v11p_sd15_inpaint_fp16.yaml
# Downloading ControlNet config : control_v11p_sd15_lineart_fp16.yaml
# Downloading ControlNet config : control_v11p_sd15_mlsd_fp16.yaml
# Downloading ControlNet config : control_v11p_sd15_normalbae_fp16.yaml
# Downloading ControlNet config : control_v11p_sd15_openpose_fp16.yaml
# Downloading ControlNet config : control_v11p_sd15_scribble_fp16.yaml
# Downloading ControlNet config : control_v11p_sd15_seg_fp16.yaml
# Downloading ControlNet config : control_v11p_sd15_softedge_fp16.yaml
# Downloading ControlNet config : control_v11p_sd15s2_lineart_anime_fp16.yaml
# Downloading ControlNet config : control_v11f1e_sd15_tile_fp16.yaml
# Downloading Stable Diffusion model file : ColorBombMix-fp16-no-ema.safetensors
# VAE kl_f8_anime2 will be downloaded as recommended by this model.
# Downloading embedding (textual inversion): bad-artist.pt
# Downloading embedding (textual inversion): bad-artist-anime.pt
# Downloading embedding (textual inversion): bad-hands-5.pt
# Downloading embedding (textual inversion): bad_prompt.pt
# Downloading embedding (textual inversion): bad_prompt_version2.pt
# Downloading embedding (textual inversion): EasyNegative.pt
# Downloading embedding (textual inversion): ng_deepnegative_v1_75t.pt
# Downloading embedding (textual inversion): Unspeakable-Horrors-64v.pt
# Downloading embedding (textual inversion): bad-image-v2-39000.pt
# Downloading LoRA: epiNoiseoffset_v2.safetensors
# Downloading LoRA: animeLineartMangaLike_v30MangaLike.safetensors
# Downloading VAE: Anything-V3.0.vae.pt
# Downloading VAE: anything-v4.0.vae.pt
# Downloading VAE: grapefruit.vae.pt
# Downloading VAE: kl-f8-anime2.ckpt
# Downloading VAE: orangemix.vae.pt
# Downloading VAE: RandoMix3.vae.pt
# Downloading VAE: RefSlave-vae.pt
# Downloading upscaler: 4x-UltraSharp.pth
# Hotfixes (if any):
# Fixing Deforum x ControlNet 'folder not found' error
# Fixing some memory management
# Moving to :
# /content/stable-diffusion-webui
# QoL improvements (if any):
# Adding vae list and clipskip slider near models list in webui
# Running launch.py. From there, it's webui's code.
# Python 3.10.12 (main, Jun  7 2023, 12:45:35) [GCC 9.4.0]
# Commit hash: 22bcc7be428c94e9408f589966c2040187245d81
# Installing gfpgan
# Installing clip
# Installing open_clip
# Cloning Stable Diffusion into /content/stable-diffusion-webui/repositories/stable-diffusion-stability-ai...
# Cloning Taming Transformers into /content/stable-diffusion-webui/repositories/taming-transformers...
# Cloning K-diffusion into /content/stable-diffusion-webui/repositories/k-diffusion...
# Cloning CodeFormer into /content/stable-diffusion-webui/repositories/CodeFormer...
# Cloning BLIP into /content/stable-diffusion-webui/repositories/BLIP...
# Installing requirements for CodeFormer
# Installing requirements for Web UI
# Installing pycloudflared
#
#
# Installing rembg
# Installing onnxruntime for REMBG extension
# Installing pymatting for REMBG extension
#
# Installing sd-webui-controlnet requirement: mediapipe
# Installing sd-webui-controlnet requirement: svglib
# Installing sd-webui-controlnet requirement: fvcore
#
# Installing ImageReward requirement for image browser
#
#
# Installing requirements for CivitAI Browser
#
# Downloading pose_landmark_full.tflite...
# Downloading pose_web.binarypb...
# Downloading pose_solution_packed_assets.data...
# Downloading pose_solution_simd_wasm_bin.wasm...
# Downloading pose_solution_packed_assets_loader.js...
# Downloading pose_solution_simd_wasm_bin.js...
#
# Launching Web UI with arguments: --xformers --enable-insecure-extension-access --gradio-queue --multiple --theme dark --ckpt /content/stable-diffusion-webui/models/Stable-diffusion/ColorBombMix-fp16-no-ema.safetensors --vae-path /content/stable-diffusion-webui/models/VAE/vae-ft-mse-840000-ema-pruned.safetensors
# 2023-06-27 00:30:13.303618: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# /usr/local/lib/python3.10/dist-packages/torchvision/transforms/functional_tensor.py:5: UserWarning: The torchvision.transforms.functional_tensor module is deprecated in 0.15 and will be **removed in 0.17**. Please don't rely on it. You probably just need to use APIs in torchvision.transforms.functional or in torchvision.transforms.v2.functional.
#   warnings.warn(
# Additional Network extension not installed, Only hijack built-in lora
# LoCon Extension hijack built-in lora successfully
# [AddNet] Updating model hashes...
# 100% 2/2 [00:00<00:00,  6.11it/s]
# [AddNet] Updating model hashes...
# 100% 2/2 [00:00<00:00, 3512.82it/s]
# 2023-06-27 00:30:21,784 - ControlNet - INFO - ControlNet v1.1.227
# ControlNet preprocessor location: /content/stable-diffusion-webui/extensions/sd-webui-controlnet/annotator/downloads
# 2023-06-27 00:30:21,964 - ControlNet - INFO - ControlNet v1.1.227
# all detected, remote.moe trying to connect...
# Warning: Permanently added 'localhost.run,54.161.197.247' (RSA) to the list of known hosts.
# all detected, cloudflared trying to connect...
# Download cloudflared...: 100% 35.1M/35.1M [00:00<00:00, 492MB/s]
# Image Browser: ImageReward is not installed, cannot be used.
# Image Browser: Creating database
# Image Browser: Database created
# Calculating sha256 for /content/stable-diffusion-webui/models/Stable-diffusion/ColorBombMix-fp16-no-ema.safetensors: 627f50eea879bafd7ae7c3b55485eb921787c996ec383ba5b51eb3475051a597
# Loading weights [627f50eea8] from /content/stable-diffusion-webui/models/Stable-diffusion/ColorBombMix-fp16-no-ema.safetensors
# Creating model from config: /content/stable-diffusion-webui/configs/v1-inference.yaml
# LatentDiffusion: Running in eps-prediction mode
# DiffusionWrapper has 859.52 M params.
# Downloading (…)olve/main/vocab.json: 100% 961k/961k [00:00<00:00, 1.01MB/s]
# Downloading (…)olve/main/merges.txt: 100% 525k/525k [00:00<00:00, 2.12MB/s]
# Downloading (…)cial_tokens_map.json: 100% 389/389 [00:00<00:00, 2.09MB/s]
# Downloading (…)okenizer_config.json: 100% 905/905 [00:00<00:00, 6.01MB/s]
# Downloading (…)lve/main/config.json: 100% 4.52k/4.52k [00:00<00:00, 19.7MB/s]
# Loading VAE weights from commandline argument: /content/stable-diffusion-webui/models/VAE/vae-ft-mse-840000-ema-pruned.safetensors
# Applying xformers cross attention optimization.
# Textual inversion embeddings loaded(9): bad-hands-5, Unspeakable-Horrors-64v, bad-artist-anime, bad_prompt_version2, bad_prompt, bad-image-v2-39000, EasyNegative, ng_deepnegative_v1_75t, bad-artist
# Model loaded in 16.7s (calculate hash: 6.7s, load weights from disk: 0.3s, create model: 6.1s, apply weights to model: 1.7s, load VAE: 1.8s, load textual inversion embeddings: 0.1s).
# Public WebUI Colab URL: None
# Public WebUI Colab URL: https://60f3272d-067d-410c.gradio.live
# Public WebUI Colab URL: https://fec51798274638.lhr.life
# Public WebUI Colab URL: https://column-maritime-street-committees.trycloudflare.com
# Startup time: 61.8s (import torch: 4.0s, import gradio: 0.9s, import ldm: 2.0s, other imports: 1.6s, setup codeformer: 0.2s, load scripts: 34.4s, load SD checkpoint: 16.8s, create ui: 1.7s, gradio launch: 0.2s).
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: send2trash~=1.8 in /usr/local/lib/python3.10/dist-packages (1.8.2)
# Collecting dynamicprompts[attentiongrabber,magicprompt]~=0.27.0
#   Downloading dynamicprompts-0.27.0-py2.py3-none-any.whl (48 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 48.0/48.0 kB 3.6 MB/s eta 0:00:00
# Requirement already satisfied: jinja2~=3.1 in /usr/local/lib/python3.10/dist-packages (from dynamicprompts[attentiongrabber,magicprompt]~=0.27.0) (3.1.2)
# Requirement already satisfied: pyparsing~=3.0 in /usr/local/lib/python3.10/dist-packages (from dynamicprompts[attentiongrabber,magicprompt]~=0.27.0) (3.1.0)
# Requirement already satisfied: transformers[torch]~=4.19 in /usr/local/lib/python3.10/dist-packages (from dynamicprompts[attentiongrabber,magicprompt]~=0.27.0) (4.25.1)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2~=3.1->dynamicprompts[attentiongrabber,magicprompt]~=0.27.0) (2.1.3)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from transformers[torch]~=4.19->dynamicprompts[attentiongrabber,magicprompt]~=0.27.0) (3.12.2)
# Requirement already satisfied: huggingface-hub<1.0,>=0.10.0 in /usr/local/lib/python3.10/dist-packages (from transformers[torch]~=4.19->dynamicprompts[attentiongrabber,magicprompt]~=0.27.0) (0.15.1)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from transformers[torch]~=4.19->dynamicprompts[attentiongrabber,magicprompt]~=0.27.0) (1.23.3)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from transformers[torch]~=4.19->dynamicprompts[attentiongrabber,magicprompt]~=0.27.0) (23.1)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from transformers[torch]~=4.19->dynamicprompts[attentiongrabber,magicprompt]~=0.27.0) (6.0)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers[torch]~=4.19->dynamicprompts[attentiongrabber,magicprompt]~=0.27.0) (2022.10.31)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from transformers[torch]~=4.19->dynamicprompts[attentiongrabber,magicprompt]~=0.27.0) (2.25.1)
# Requirement already satisfied: tokenizers!=0.11.3,<0.14,>=0.11.1 in /usr/local/lib/python3.10/dist-packages (from transformers[torch]~=4.19->dynamicprompts[attentiongrabber,magicprompt]~=0.27.0) (0.13.3)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.10/dist-packages (from transformers[torch]~=4.19->dynamicprompts[attentiongrabber,magicprompt]~=0.27.0) (4.65.0)
# Requirement already satisfied: torch!=1.12.0,>=1.7 in /usr/local/lib/python3.10/dist-packages (from transformers[torch]~=4.19->dynamicprompts[attentiongrabber,magicprompt]~=0.27.0) (2.0.0+cu118)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.10.0->transformers[torch]~=4.19->dynamicprompts[attentiongrabber,magicprompt]~=0.27.0) (2023.6.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.10.0->transformers[torch]~=4.19->dynamicprompts[attentiongrabber,magicprompt]~=0.27.0) (4.6.3)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch!=1.12.0,>=1.7->transformers[torch]~=4.19->dynamicprompts[attentiongrabber,magicprompt]~=0.27.0) (1.11.1)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch!=1.12.0,>=1.7->transformers[torch]~=4.19->dynamicprompts[attentiongrabber,magicprompt]~=0.27.0) (3.1)
# Requirement already satisfied: triton==2.0.0 in /usr/local/lib/python3.10/dist-packages (from torch!=1.12.0,>=1.7->transformers[torch]~=4.19->dynamicprompts[attentiongrabber,magicprompt]~=0.27.0) (2.0.0)
# Requirement already satisfied: cmake in /usr/local/lib/python3.10/dist-packages (from triton==2.0.0->torch!=1.12.0,>=1.7->transformers[torch]~=4.19->dynamicprompts[attentiongrabber,magicprompt]~=0.27.0) (3.25.2)
# Requirement already satisfied: lit in /usr/local/lib/python3.10/dist-packages (from triton==2.0.0->torch!=1.12.0,>=1.7->transformers[torch]~=4.19->dynamicprompts[attentiongrabber,magicprompt]~=0.27.0) (16.0.6)
# Requirement already satisfied: chardet<5,>=3.0.2 in /usr/local/lib/python3.10/dist-packages (from requests->transformers[torch]~=4.19->dynamicprompts[attentiongrabber,magicprompt]~=0.27.0) (4.0.0)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->transformers[torch]~=4.19->dynamicprompts[attentiongrabber,magicprompt]~=0.27.0) (2.10)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->transformers[torch]~=4.19->dynamicprompts[attentiongrabber,magicprompt]~=0.27.0) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->transformers[torch]~=4.19->dynamicprompts[attentiongrabber,magicprompt]~=0.27.0) (2023.5.7)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch!=1.12.0,>=1.7->transformers[torch]~=4.19->dynamicprompts[attentiongrabber,magicprompt]~=0.27.0) (1.3.0)
# Installing collected packages: dynamicprompts
# Successfully installed dynamicprompts-0.27.0
# sd-dynamic-prompts installer: running /usr/bin/python3 -m pip install 'send2trash~=1.8' 'dynamicprompts[attentiongrabber,magicprompt]~=0.27.0'
#
# Error completing request
# Arguments: ('', 'https://github.com/adieyal/sd-dynamic-prompts.git') {}
# Traceback (most recent call last):
#   File "/content/stable-diffusion-webui/modules/call_queue.py", line 56, in f
#     res = list(func(*args, **kwargs))
#   File "/content/stable-diffusion-webui/modules/ui_extensions.py", line 144, in install_extension_from_url
#     assert not os.path.exists(target_dir), f'Extension directory already exists: {target_dir}'
# AssertionError: Extension directory already exists: /content/stable-diffusion-webui/extensions/sd-dynamic-prompts
#
#
# #######################################################################################################
# Initializing Civitai Link
# If submitting an issue on github, please provide the below text for debugging purposes:
#
# Python revision: 3.10.12 (main, Jun  7 2023, 12:45:35) [GCC 9.4.0]
# Civitai Link revision: 2dfc03c17304278ca0b456366cc7871a2af8377b
# SD-WebUI revision: 22bcc7be428c94e9408f589966c2040187245d81
#
# Checking Civitai Link requirements...
# [+] python-socketio[client] version 5.7.2 installed.
#
# #######################################################################################################
#
# Closing server running on port: 7860
# Restarting UI...
# Additional Network extension not installed, Only hijack built-in lora
# LoCon Extension hijack built-in lora successfully
# [AddNet] Updating model hashes...
# 100% 2/2 [00:00<00:00, 3298.71it/s]
# 2023-06-27 00:45:06,666 - ControlNet - INFO - ControlNet v1.1.227
# all detected, remote.moe trying to connect...
# all detected, cloudflared trying to connect...
# Civitai: API loaded
# Image Browser: ImageReward is not installed, cannot be used.
# Public WebUI Colab URL: None
# Public WebUI Colab URL: https://60f3272d-067d-410c.gradio.live
# Public WebUI Colab URL: https://d064c2e1a54d70.lhr.life
# Public WebUI Colab URL: https://column-maritime-street-committees.trycloudflare.com
# Civitai: Check resources for missing preview images
# Startup time: 11.6s (load scripts: 9.7s, create ui: 1.7s, gradio launch: 0.2s).
# Calculating sha256 for /content/stable-diffusion-webui/embeddings/negative/EasyNegative.pt: 66a7279a88dd0cb17afbc88560540c638336d5783fd6b191c53c0d654e25b9db
# Calculating sha256 for /content/stable-diffusion-webui/embeddings/negative/Unspeakable-Horrors-64v.pt: a56065e1bc55917fac0b870ea38053e2a18c6b6d500bbeb090d69269fbe112d7
# Calculating sha256 for /content/stable-diffusion-webui/embeddings/negative/bad-artist-anime.pt: 5f7bea88750c97a0b8c9ba9f5bc0d13648c3a17a69aaac855903229d5f58c34b
# Calculating sha256 for /content/stable-diffusion-webui/embeddings/negative/bad-artist.pt: 2d356134903e8f47bf6cf519bdf577cdcee42fc717ef264498162e94f130843a
# Calculating sha256 for /content/stable-diffusion-webui/embeddings/negative/bad-hands-5.pt: aa7651be154c46a2f4868788ef84a92b3083b0c0c5c46f5012a56698bfd2a1ba
# Calculating sha256 for /content/stable-diffusion-webui/embeddings/negative/bad-image-v2-39000.pt: 5b9281d7c6adc221b8ea9067b678f4b6ff4cc94735e2d50885070380d5496037
# Calculating sha256 for /content/stable-diffusion-webui/embeddings/negative/bad_prompt.pt: f9dfe1c982e2a1917054fa827ee1f981c6e6102984f981c691e4f8c817e292cb
# Calculating sha256 for /content/stable-diffusion-webui/embeddings/negative/bad_prompt_version2.pt: 6f35e7dd816ae04bb3f774a9a17ebfbc50c0e3a53f69a9a40bed05936d3a3812
# Calculating sha256 for /content/stable-diffusion-webui/embeddings/negative/ng_deepnegative_v1_75t.pt: 54e7e4826d53949a3d0dde40aea023b1e456a618c608a7630e3999fd38f93245
# Calculating sha256 for /content/stable-diffusion-webui/models/Stable-diffusion/instruct-pix2pix-00-22000.safetensors: fbc31a67aab29ad38eef622a252d3fa4b0a81d4a4dc65da416cf45b13aa67688
# Calculating sha256 for /content/stable-diffusion-webui/models/VAE/Anything-V3.0.vae.pt: f921fb3f29891d2a77a6571e56b8b5052420d2884129517a333c60b1b4816cdf
# Calculating sha256 for /content/stable-diffusion-webui/models/VAE/RandoMix3.vae.pt: c6a580b13a5bc05a5e16e4dbb80608ff2ec251a162311590c1f34c013d7f3dab
# Calculating sha256 for /content/stable-diffusion-webui/models/VAE/RefSlave-vae.pt: f921fb3f29891d2a77a6571e56b8b5052420d2884129517a333c60b1b4816cdf
# Calculating sha256 for /content/stable-diffusion-webui/models/VAE/anything-v4.0.vae.pt: f921fb3f29891d2a77a6571e56b8b5052420d2884129517a333c60b1b4816cdf
# Calculating sha256 for /content/stable-diffusion-webui/models/VAE/grapefruit.vae.pt: f921fb3f29891d2a77a6571e56b8b5052420d2884129517a333c60b1b4816cdf
# Calculating sha256 for /content/stable-diffusion-webui/models/VAE/kl-f8-anime2.ckpt: df3c506e51b7ee1d7b5a6a2bb7142d47d488743c96aa778afb0f53a2cdc2d38d
# Calculating sha256 for /content/stable-diffusion-webui/models/VAE/orangemix.vae.pt: f921fb3f29891d2a77a6571e56b8b5052420d2884129517a333c60b1b4816cdf
# Calculating sha256 for /content/stable-diffusion-webui/models/VAE/vae-ft-mse-840000-ema-pruned.safetensors: 735e4c3a447a3255760d7f86845f09f937809baa529c17370d83e4c3758f3c75
# Civitai: Found 11 resources missing preview images
# Civitai: Found 10 hash matches
# Civitai: Downloading: "https://image.civitai.com/xG1nkqKTMzGDvpLrqFT7WA/5fdc47cf-9cf1-4c3a-0a0e-df8304a24a00/width=450/79832.jpeg" to /content/stable-diffusion-webui/models/Stable-diffusion/ColorBombMix-fp16-no-ema.preview.png
#
# 67.4kB [00:00, 35.6MB/s]
# Civitai: Downloading: "https://image.civitai.com/xG1nkqKTMzGDvpLrqFT7WA/4a559d45-70c9-478f-b22d-fd669010b500/width=450/93874.jpeg" to /content/stable-diffusion-webui/embeddings/negative/bad_prompt.preview.png
#
# 49.0kB [00:00, 52.7MB/s]
# Civitai: Downloading: "https://image.civitai.com/xG1nkqKTMzGDvpLrqFT7WA/b1ebed82-d4e3-4213-d4dd-8b2b7696ba00/width=450/52079.jpeg" to /content/stable-diffusion-webui/embeddings/negative/bad-artist-anime.preview.png
#
# 105kB [00:00, 50.3MB/s]
# Civitai: Downloading: "https://image.civitai.com/xG1nkqKTMzGDvpLrqFT7WA/0f12ec45-0d26-4e15-0bb1-6e23230d8700/width=450/656105.jpeg" to /content/stable-diffusion-webui/embeddings/negative/bad_prompt_version2.preview.png
#
# 123kB [00:00, 30.8MB/s]
# Civitai: Downloading: "https://image.civitai.com/xG1nkqKTMzGDvpLrqFT7WA/bf650aea-0db1-4b0c-9191-9a48be35d700/width=450/91997.jpeg" to /content/stable-diffusion-webui/embeddings/negative/EasyNegative.preview.png
#
# 164kB [00:00, 42.8MB/s]
# Civitai: Downloading: "https://image.civitai.com/xG1nkqKTMzGDvpLrqFT7WA/75837fad-48dc-4116-44f6-acb4e83ca600/width=450/37886.jpeg" to /content/stable-diffusion-webui/embeddings/negative/Unspeakable-Horrors-64v.preview.png
#
# 59.7kB [00:00, 75.1MB/s]
# Civitai: Downloading: "https://image.civitai.com/xG1nkqKTMzGDvpLrqFT7WA/cb4bd554-c7ed-4837-3803-8f24fa8fc900/width=450/52078.jpeg" to /content/stable-diffusion-webui/embeddings/negative/bad-artist.preview.png
#
# 105kB [00:00, 32.2MB/s]
# Civitai: Downloading: "https://image.civitai.com/xG1nkqKTMzGDvpLrqFT7WA/f7fe0b31-86a6-48ff-4fc2-906227af9300/width=450/45555.jpeg" to /content/stable-diffusion-webui/embeddings/negative/ng_deepnegative_v1_75t.preview.png
#
# 42.7kB [00:00, 121MB/s]
# Civitai: File already exists: /content/stable-diffusion-webui/embeddings/negative/bad_prompt.preview.png
# Civitai: Downloading: "https://image.civitai.com/xG1nkqKTMzGDvpLrqFT7WA/cc2322d0-327f-4c2b-970e-562928f32800/width=450/59434.jpeg" to /content/stable-diffusion-webui/embeddings/negative/bad_prompt.preview.png
#
# 50.8kB [00:00, 50.8MB/s]
# Civitai: File already exists: /content/stable-diffusion-webui/embeddings/negative/bad-artist.preview.png
# Civitai: Downloading: "https://image.civitai.com/xG1nkqKTMzGDvpLrqFT7WA/b64c975c-ebd2-4131-f9d4-42bb6e32ab00/width=450/464576.jpeg" to /content/stable-diffusion-webui/embeddings/negative/bad-artist.preview.png
#
# 26.1kB [00:00, 45.2MB/s]
# Civitai: Updated 10 preview images
# Civitai Link: Connected to Civitai Link Server
# Civitai Link: Joined room
# Civitai Link: Presence update: SD: 16, Clients: 0
# Civitai Link: Joined room fad68e
# Civitai Link: Link Key upgraded
# Civitai Link: Presence update: SD: 1, Clients: 1
# Civitai Link: Connected to Civitai Instance
# Civitai Link: Incoming Command: activities:list
# Civitai Link: Joined room 5d9b55b31fd5bf2b696031f4974ff2aee571196b7569de52c18aed52d4db95c99eb540fa60f8aaad9ee366437109d2cd3bdb1a37ecf53a0b2ab6c137b5af68b9
# Civitai Link: Presence update: SD: 0, Clients: 1
# Civitai Link: Disconnected from Civitai Instance
# Civitai Link: Presence update: SD: 1, Clients: 1
# Civitai Link: Connected to Civitai Instance
# Civitai Link: Incoming Command: resources:list
# Civitai Link: Incoming Command: activities:list
# Civitai Link: Incoming Command: resources:list
# Closing server running on port: 7860
# Restarting UI...
# Additional Network extension not installed, Only hijack built-in lora
# LoCon Extension hijack built-in lora successfully
# [AddNet] Updating model hashes...
# 100% 2/2 [00:00<00:00, 3326.17it/s]
# 2023-06-27 00:51:46,104 - ControlNet - INFO - ControlNet v1.1.227
# all detected, remote.moe trying to connect...
# Warning: Permanently added the RSA host key for IP address '35.171.254.69' to the list of known hosts.
# all detected, cloudflared trying to connect...
# Civitai: API loaded
# Image Browser: ImageReward is not installed, cannot be used.
# Public WebUI Colab URL: None
# Public WebUI Colab URL: https://60f3272d-067d-410c.gradio.live
# Public WebUI Colab URL: https://4e1857fafe3090.lhr.life
# Public WebUI Colab URL: https://column-maritime-street-committees.trycloudflare.com
# Civitai Link: Connecting to Civitai Link Server
# Civitai: Check resources for missing preview images
# Startup time: 12.7s (load scripts: 11.2s, create ui: 1.3s, gradio launch: 0.2s).
# Civitai: Found 3 resources missing preview images
# Civitai Link: Joined room 5d9b55b31fd5bf2b696031f4974ff2aee571196b7569de52c18aed52d4db95c99eb540fa60f8aaad9ee366437109d2cd3bdb1a37ecf53a0b2ab6c137b5af68b9
# Civitai: No preview images found on Civitai
# Civitai Link: Presence update: SD: 0, Clients: 1
# Civitai Link: Disconnected from Civitai Instance
# Civitai Link: Presence update: SD: 1, Clients: 1
# Civitai Link: Connected to Civitai Instance
# Civitai Link: Incoming Command: activities:list
# Civitai Link: Incoming Command: resources:list
# Task exception was never retrieved
# future: <Task finished name='exwxgcybge_1587' coro=<Queue.process_events() done, defined at /usr/local/lib/python3.10/dist-packages/gradio/queueing.py:343> exception=ValidationError(model='PredictBody', errors=[{'loc': ('data',), 'msg': 'field required', 'type': 'value_error.missing'}])>
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/gradio/queueing.py", line 347, in process_events
#     client_awake = await self.gather_event_data(event)
#   File "/usr/local/lib/python3.10/dist-packages/gradio/queueing.py", line 220, in gather_event_data
#     data, client_awake = await self.get_message(event, timeout=receive_timeout)
#   File "/usr/local/lib/python3.10/dist-packages/gradio/queueing.py", line 456, in get_message
#     return PredictBody(**data), True
#   File "pydantic/main.py", line 341, in pydantic.main.BaseModel.__init__
# pydantic.error_wrappers.ValidationError: 1 validation error for PredictBody
# data
#   field required (type=value_error.missing)
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/gradio/routes.py", line 394, in run_predict
#     output = await app.get_blocks().process_api(
#   File "/usr/local/lib/python3.10/dist-packages/gradio/blocks.py", line 1075, in process_api
#     result = await self.call_function(
#   File "/usr/local/lib/python3.10/dist-packages/gradio/blocks.py", line 884, in call_function
#     prediction = await anyio.to_thread.run_sync(
#   File "/usr/local/lib/python3.10/dist-packages/anyio/to_thread.py", line 33, in run_sync
#     return await get_asynclib().run_sync_in_worker_thread(
#   File "/usr/local/lib/python3.10/dist-packages/anyio/_backends/_asyncio.py", line 877, in run_sync_in_worker_thread
#     return await future
#   File "/usr/local/lib/python3.10/dist-packages/anyio/_backends/_asyncio.py", line 807, in run
#     result = context.run(func, *args)
#   File "/content/stable-diffusion-webui/modules/ui.py", line 1529, in reload_scripts
#     modules.scripts.reload_script_body_only()
#   File "/content/stable-diffusion-webui/modules/scripts.py", line 510, in reload_script_body_only
#     scripts_txt2img.reload_sources(cache)
#   File "/content/stable-diffusion-webui/modules/scripts.py", line 491, in reload_sources
#     module = script_loading.load_module(script.filename)
#   File "/content/stable-diffusion-webui/modules/script_loading.py", line 11, in load_module
#     module_spec.loader.exec_module(module)
#   File "<frozen importlib._bootstrap_external>", line 883, in exec_module
#   File "<frozen importlib._bootstrap>", line 241, in _call_with_frames_removed
#   File "/content/stable-diffusion-webui/extensions/sd-webui-controlnet/scripts/controlnet.py", line 14, in <module>
#     importlib.reload(processor)
#   File "/usr/lib/python3.10/importlib/__init__.py", line 168, in reload
#     raise ModuleNotFoundError(f"spec not found for the module {name!r}", name=name)
# ModuleNotFoundError: spec not found for the module 'scripts.processor'
# ^C

# %%
#@title Reconnect
#@markdown In case the above cell stop running, if the webui loses connection to Colab, or if you unintentionally refresh this page, use this cell to re-enact your environment without reinstalling everything. You will find your work intact.

###########################
##### MOUNT GDRIVE #####
###########################

from google.colab import drive
drive.mount('/content/drive')

###########################
##### LAUNCHING WEBUI #####
###########################

#  https://github.com/kwalker7631/sd_civitai_extension.git
#  https://github.com/adieyal/sd-dynamic-prompts.git

with open("launch.py") as f:
    if "skip_install = False" in f.read():
        print("Setting skip_install to True in launch.py")
        # !sed -i "s/skip_install = False/skip_install = True/" launch.py

print("Running launch.py. From there, it's webui's code.")
# !python launch.py --xformers --enable-insecure-extension-access --gradio-queue --multiple $dark --ckpt $ckpt_arg --vae-path $vaes_folder/vae-ft-mse-840000-ema-pruned.safetensors
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# Running launch.py. From there, it's webui's code.
# Python 3.10.12 (main, Jun  7 2023, 12:45:35) [GCC 9.4.0]
# Commit hash: 22bcc7be428c94e9408f589966c2040187245d81
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: send2trash~=1.8 in /usr/local/lib/python3.10/dist-packages (1.8.2)
# Requirement already satisfied: dynamicprompts[attentiongrabber,magicprompt]~=0.27.0 in /usr/local/lib/python3.10/dist-packages (0.27.0)
# Requirement already satisfied: jinja2~=3.1 in /usr/local/lib/python3.10/dist-packages (from dynamicprompts[attentiongrabber,magicprompt]~=0.27.0) (3.1.2)
# Requirement already satisfied: pyparsing~=3.0 in /usr/local/lib/python3.10/dist-packages (from dynamicprompts[attentiongrabber,magicprompt]~=0.27.0) (3.1.0)
# Requirement already satisfied: transformers[torch]~=4.19 in /usr/local/lib/python3.10/dist-packages (from dynamicprompts[attentiongrabber,magicprompt]~=0.27.0) (4.25.1)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2~=3.1->dynamicprompts[attentiongrabber,magicprompt]~=0.27.0) (2.1.3)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from transformers[torch]~=4.19->dynamicprompts[attentiongrabber,magicprompt]~=0.27.0) (3.12.2)
# Requirement already satisfied: huggingface-hub<1.0,>=0.10.0 in /usr/local/lib/python3.10/dist-packages (from transformers[torch]~=4.19->dynamicprompts[attentiongrabber,magicprompt]~=0.27.0) (0.15.1)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from transformers[torch]~=4.19->dynamicprompts[attentiongrabber,magicprompt]~=0.27.0) (1.23.3)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from transformers[torch]~=4.19->dynamicprompts[attentiongrabber,magicprompt]~=0.27.0) (23.1)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from transformers[torch]~=4.19->dynamicprompts[attentiongrabber,magicprompt]~=0.27.0) (6.0)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers[torch]~=4.19->dynamicprompts[attentiongrabber,magicprompt]~=0.27.0) (2022.10.31)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from transformers[torch]~=4.19->dynamicprompts[attentiongrabber,magicprompt]~=0.27.0) (2.25.1)
# Requirement already satisfied: tokenizers!=0.11.3,<0.14,>=0.11.1 in /usr/local/lib/python3.10/dist-packages (from transformers[torch]~=4.19->dynamicprompts[attentiongrabber,magicprompt]~=0.27.0) (0.13.3)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.10/dist-packages (from transformers[torch]~=4.19->dynamicprompts[attentiongrabber,magicprompt]~=0.27.0) (4.65.0)
# Requirement already satisfied: torch!=1.12.0,>=1.7 in /usr/local/lib/python3.10/dist-packages (from transformers[torch]~=4.19->dynamicprompts[attentiongrabber,magicprompt]~=0.27.0) (2.0.0+cu118)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.10.0->transformers[torch]~=4.19->dynamicprompts[attentiongrabber,magicprompt]~=0.27.0) (2023.6.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.10.0->transformers[torch]~=4.19->dynamicprompts[attentiongrabber,magicprompt]~=0.27.0) (4.6.3)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch!=1.12.0,>=1.7->transformers[torch]~=4.19->dynamicprompts[attentiongrabber,magicprompt]~=0.27.0) (1.11.1)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch!=1.12.0,>=1.7->transformers[torch]~=4.19->dynamicprompts[attentiongrabber,magicprompt]~=0.27.0) (3.1)
# Requirement already satisfied: triton==2.0.0 in /usr/local/lib/python3.10/dist-packages (from torch!=1.12.0,>=1.7->transformers[torch]~=4.19->dynamicprompts[attentiongrabber,magicprompt]~=0.27.0) (2.0.0)
# Requirement already satisfied: cmake in /usr/local/lib/python3.10/dist-packages (from triton==2.0.0->torch!=1.12.0,>=1.7->transformers[torch]~=4.19->dynamicprompts[attentiongrabber,magicprompt]~=0.27.0) (3.25.2)
# Requirement already satisfied: lit in /usr/local/lib/python3.10/dist-packages (from triton==2.0.0->torch!=1.12.0,>=1.7->transformers[torch]~=4.19->dynamicprompts[attentiongrabber,magicprompt]~=0.27.0) (16.0.6)
# Requirement already satisfied: chardet<5,>=3.0.2 in /usr/local/lib/python3.10/dist-packages (from requests->transformers[torch]~=4.19->dynamicprompts[attentiongrabber,magicprompt]~=0.27.0) (4.0.0)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->transformers[torch]~=4.19->dynamicprompts[attentiongrabber,magicprompt]~=0.27.0) (2.10)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->transformers[torch]~=4.19->dynamicprompts[attentiongrabber,magicprompt]~=0.27.0) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->transformers[torch]~=4.19->dynamicprompts[attentiongrabber,magicprompt]~=0.27.0) (2023.5.7)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch!=1.12.0,>=1.7->transformers[torch]~=4.19->dynamicprompts[attentiongrabber,magicprompt]~=0.27.0) (1.3.0)
# sd-dynamic-prompts installer: running /usr/bin/python3 -m pip install 'send2trash~=1.8' 'dynamicprompts[attentiongrabber,magicprompt]~=0.27.0'
#
#
#
#
# loading Smart Crop reqs from /content/stable-diffusion-webui/extensions/sd_smartprocess/requirements.txt
# Checking Smart Crop requirements.
#
#
#
#
#
# #######################################################################################################
# Initializing Civitai Link
# If submitting an issue on github, please provide the below text for debugging purposes:
#
# Python revision: 3.10.12 (main, Jun  7 2023, 12:45:35) [GCC 9.4.0]
# Civitai Link revision: 2dfc03c17304278ca0b456366cc7871a2af8377b
# SD-WebUI revision: 22bcc7be428c94e9408f589966c2040187245d81
#
# Checking Civitai Link requirements...
# [+] python-socketio[client] version 5.7.2 installed.
#
# #######################################################################################################
#
#
#
#
#
#
#
# Launching Web UI with arguments: --xformers --enable-insecure-extension-access --gradio-queue --multiple --theme dark --ckpt /content/stable-diffusion-webui/models/Stable-diffusion/ColorBombMix-fp16-no-ema.safetensors --vae-path /content/stable-diffusion-webui/models/VAE/vae-ft-mse-840000-ema-pruned.safetensors
# 2023-06-27 02:04:38.016427: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# /usr/local/lib/python3.10/dist-packages/torchvision/transforms/functional_tensor.py:5: UserWarning: The torchvision.transforms.functional_tensor module is deprecated in 0.15 and will be **removed in 0.17**. Please don't rely on it. You probably just need to use APIs in torchvision.transforms.functional or in torchvision.transforms.v2.functional.
#   warnings.warn(
# Additional Network extension not installed, Only hijack built-in lora
# LoCon Extension hijack built-in lora successfully
# [AddNet] Updating model hashes...
# 100% 2/2 [00:00<00:00, 1476.09it/s]
# [AddNet] Updating model hashes...
# 100% 2/2 [00:00<00:00, 3021.83it/s]
# Error loading script: bluescape_upload.py
# Traceback (most recent call last):
#   File "/content/stable-diffusion-webui/modules/scripts.py", line 256, in load_scripts
#     script_module = script_loading.load_module(scriptfile.path)
#   File "/content/stable-diffusion-webui/modules/script_loading.py", line 11, in load_module
#     module_spec.loader.exec_module(module)
#   File "<frozen importlib._bootstrap_external>", line 883, in exec_module
#   File "<frozen importlib._bootstrap>", line 241, in _call_with_frames_removed
#   File "/content/stable-diffusion-webui/extensions/sd-webui-bluescape/scripts/bluescape_upload.py", line 25, in <module>
#     from bs.bluescape_upload import Script
#   File "/content/stable-diffusion-webui/extensions/sd-webui-bluescape/bs/__init__.py", line 26, in <module>
#     from .extension import BluescapeUploadManager
#   File "/content/stable-diffusion-webui/extensions/sd-webui-bluescape/bs/extension.py", line 37, in <module>
#     import pkce
# ModuleNotFoundError: No module named 'pkce'
#
# 2023-06-27 02:04:47,757 - ControlNet - INFO - ControlNet v1.1.227
# ControlNet preprocessor location: /content/stable-diffusion-webui/extensions/sd-webui-controlnet/annotator/downloads
# 2023-06-27 02:04:47,979 - ControlNet - INFO - ControlNet v1.1.227
# all detected, remote.moe trying to connect...
# all detected, cloudflared trying to connect...
# Civitai: API loaded
# Error loading script: main.py
# Traceback (most recent call last):
#   File "/content/stable-diffusion-webui/modules/scripts.py", line 256, in load_scripts
#     script_module = script_loading.load_module(scriptfile.path)
#   File "/content/stable-diffusion-webui/modules/script_loading.py", line 11, in load_module
#     module_spec.loader.exec_module(module)
#   File "<frozen importlib._bootstrap_external>", line 883, in exec_module
#   File "<frozen importlib._bootstrap>", line 241, in _call_with_frames_removed
#   File "/content/stable-diffusion-webui/extensions/stable-diffusion-webui-auto-translate-language/scripts/main.py", line 8, in <module>
#     from lru import LRU
# ModuleNotFoundError: No module named 'lru'
#
# Error loading script: trans_google.py
# Traceback (most recent call last):
#   File "/content/stable-diffusion-webui/modules/scripts.py", line 256, in load_scripts
#     script_module = script_loading.load_module(scriptfile.path)
#   File "/content/stable-diffusion-webui/modules/script_loading.py", line 11, in load_module
#     module_spec.loader.exec_module(module)
#   File "<frozen importlib._bootstrap_external>", line 883, in exec_module
#   File "<frozen importlib._bootstrap>", line 241, in _call_with_frames_removed
#   File "/content/stable-diffusion-webui/extensions/stable-diffusion-webui-auto-translate-language/scripts/trans_google.py", line 2, in <module>
#     from pygoogletranslation import Translator
# ModuleNotFoundError: No module named 'pygoogletranslation'
#
# Error loading script: trans_tp.py
# Traceback (most recent call last):
#   File "/content/stable-diffusion-webui/modules/scripts.py", line 256, in load_scripts
#     script_module = script_loading.load_module(scriptfile.path)
#   File "/content/stable-diffusion-webui/modules/script_loading.py", line 11, in load_module
#     module_spec.loader.exec_module(module)
#   File "<frozen importlib._bootstrap_external>", line 883, in exec_module
#   File "<frozen importlib._bootstrap>", line 241, in _call_with_frames_removed
#   File "/content/stable-diffusion-webui/extensions/stable-diffusion-webui-auto-translate-language/scripts/trans_tp.py", line 1, in <module>
#     import translators as ts
# ModuleNotFoundError: No module named 'translators'
#
# Image Browser: ImageReward is not installed, cannot be used.
# Loading weights [627f50eea8] from /content/stable-diffusion-webui/models/Stable-diffusion/ColorBombMix-fp16-no-ema.safetensors
# Creating model from config: /content/stable-diffusion-webui/configs/v1-inference.yaml
# LatentDiffusion: Running in eps-prediction mode
# DiffusionWrapper has 859.52 M params.
# Loading VAE weights from commandline argument: /content/stable-diffusion-webui/models/VAE/vae-ft-mse-840000-ema-pruned.safetensors
# Applying xformers cross attention optimization.
# Textual inversion embeddings loaded(12): AS-YoungV2-neg, FastNegativeV2, GS-DeMasculate-neg, bad-hands-5, Unspeakable-Horrors-64v, bad-artist-anime, bad_prompt_version2, bad_prompt, bad-image-v2-39000, EasyNegative, ng_deepnegative_v1_75t, bad-artist
# Model loaded in 16.9s (load weights from disk: 1.7s, create model: 2.0s, apply weights to model: 10.9s, load VAE: 2.0s).
# Public WebUI Colab URL: None
# Public WebUI Colab URL: https://ee45fe3e-9737-4dfa.gradio.live
# Public WebUI Colab URL: https://12866657728145.lhr.life
# Public WebUI Colab URL: https://ace-hazardous-consider-crawford.trycloudflare.com
# Civitai Link: Connecting to Civitai Link Server
# Civitai Link: Connected to Civitai Link Server
# Civitai: Check resources for missing preview images
# Startup time: 47.9s (import torch: 6.3s, import gradio: 1.3s, import ldm: 2.0s, other imports: 1.3s, setup codeformer: 0.1s, load scripts: 15.0s, load SD checkpoint: 16.9s, create ui: 3.0s, gradio launch: 0.2s, scripts app_started_callback: 1.8s).
# Civitai: Found 42 resources missing preview images
# Civitai Link: Joined room 5d9b55b31fd5bf2b696031f4974ff2aee571196b7569de52c18aed52d4db95c99eb540fa60f8aaad9ee366437109d2cd3bdb1a37ecf53a0b2ab6c137b5af68b9
# Civitai Link: Presence update: SD: 1, Clients: 1
# Civitai Link: Connected to Civitai Instance
# Civitai Link: Incoming Command: activities:list
# Civitai Link: Incoming Command: resources:list
# Civitai: Found 39 hash matches
# Civitai: Downloading: "https://image.civitai.com/xG1nkqKTMzGDvpLrqFT7WA/5fd7af96-ba7e-462d-95d1-e8c76c82baad/width=450/1272186.jpeg" to /content/stable-diffusion-webui/models/Stable-diffusion/toonyou_beta5Unstable.preview.png
#
# 72.0kB [00:00, 29.6MB/s]
# Civitai: Downloading: "https://image.civitai.com/xG1nkqKTMzGDvpLrqFT7WA/ce63e605-39a6-40af-8933-140b7e205871/width=450/1250483.jpeg" to /content/stable-diffusion-webui/models/Lora/Edob1972BuickRivieraBoattail_v1.0.preview.png
#
# 8.09MB [00:00, 27.0MB/s]
# Civitai: Downloading: "https://image.civitai.com/xG1nkqKTMzGDvpLrqFT7WA/b59514af-6e63-4e5a-b067-c95c2532f37e/width=450/1041336.jpeg" to /content/stable-diffusion-webui/models/Stable-diffusion/majicmixLux_v2.preview.png
#
# 36.3kB [00:00, 91.1MB/s]
# Civitai: Downloading: "https://image.civitai.com/xG1nkqKTMzGDvpLrqFT7WA/1317c227-0fb7-47f6-80dd-f5a23e9d4281/width=450/973528.jpeg" to /content/stable-diffusion-webui/models/Lora/Edob70Charger_v1.0.preview.png
#
# 9.88MB [00:00, 15.2MB/s]
# Civitai: Downloading: "https://image.civitai.com/xG1nkqKTMzGDvpLrqFT7WA/6d56b1a1-954b-4d86-a21f-d08ec289e848/width=450/1125322.jpeg" to /content/stable-diffusion-webui/models/Lora/maine_coon.preview.png
#
# 33.3kB [00:00, 77.1MB/s]
# Civitai: Downloading: "https://image.civitai.com/xG1nkqKTMzGDvpLrqFT7WA/aa987c25-4c43-4ea5-a23a-d51fbe3d8564/width=450/1256070.jpeg" to /content/stable-diffusion-webui/models/LyCORIS/G-STRIDER_v10.preview.png
#
# 40.3kB [00:00, 67.9MB/s]
# Civitai: Downloading: "https://image.civitai.com/xG1nkqKTMzGDvpLrqFT7WA/db363fd0-191a-406e-9c52-a79ee8f07595/width=450/1079635.jpeg" to /content/stable-diffusion-webui/models/Lora/dreamlookai_stable-diffusion-v1-5_lora_step_1200_db_851b7a81_ckp_1b22b1ba.preview.png
#
# 42.2kB [00:00, 3.76MB/s]
# Civitai: Downloading: "https://image.civitai.com/xG1nkqKTMzGDvpLrqFT7WA/bb53ded1-87bc-4562-af7c-b984c6b757a2/width=450/955312.jpeg" to /content/stable-diffusion-webui/models/Lora/[LoRa] Shoal  錦鱗 Concept (With multires noise version).preview.png
#
# 98.3kB [00:00, 552kB/s]
# Civitai: Downloading: "https://image.civitai.com/xG1nkqKTMzGDvpLrqFT7WA/3864dbc4-d1da-4ee6-8ff8-6965e55977ff/width=450/688350.jpeg" to /content/stable-diffusion-webui/models/Stable-diffusion/eclipse_v20Byakuren.preview.png
#
# 92.6kB [00:00, 13.5MB/s]
# Civitai: Downloading: "https://image.civitai.com/xG1nkqKTMzGDvpLrqFT7WA/e9ce6960-5f6b-48e6-84ea-efbf69dc5300/width=450/475912.jpeg" to /content/stable-diffusion-webui/models/LyCORIS/abs-3.preview.png
#
# 21.4kB [00:00, 63.0MB/s]
# Civitai: Downloading: "https://image.civitai.com/xG1nkqKTMzGDvpLrqFT7WA/0a1450a5-35f6-460d-b4ff-e67d923afd9f/width=450/1283672.jpeg" to /content/stable-diffusion-webui/models/Lora/Pyramid lora_Ghibli_n3.preview.png
#
# 4.90MB [00:00, 225MB/s]
# Civitai: File already exists: /content/stable-diffusion-webui/models/Lora/maine_coon.preview.png
# Civitai: Downloading: "https://image.civitai.com/xG1nkqKTMzGDvpLrqFT7WA/4bc7f342-ed9b-4346-9e8e-0221d3b1f9e4/width=450/1135558.jpeg" to /content/stable-diffusion-webui/models/Lora/maine_coon.preview.png
#
# 42.8kB [00:00, 96.0MB/s]
# Civitai: Downloading: "https://image.civitai.com/xG1nkqKTMzGDvpLrqFT7WA/fe1f1c3d-e2da-4602-8ec3-42b05c0b67cf/width=450/1047346.jpeg" to /content/stable-diffusion-webui/models/Lora/Nice forest.preview.png
#
# 53.4kB [00:00, 49.6MB/s]
# Civitai: Downloading: "https://image.civitai.com/xG1nkqKTMzGDvpLrqFT7WA/e36c55ef-aad3-488f-b49c-9a5b57b412dd/width=450/1168968.jpeg" to /content/stable-diffusion-webui/models/Lora/Chartreux_38-000002.preview.png
#
# 48.1kB [00:00, 93.8MB/s]
# Civitai: Downloading: "https://image.civitai.com/xG1nkqKTMzGDvpLrqFT7WA/b661b0c0-0346-4444-b269-2f3ee8ff9b9a/width=450/1123881.jpeg" to /content/stable-diffusion-webui/embeddings/AS-YoungV2-neg.preview.png
#
# 74.1kB [00:00, 30.8MB/s]
# Civitai: Downloading: "https://image.civitai.com/xG1nkqKTMzGDvpLrqFT7WA/b0f807e4-8990-4f23-b32c-8a39ad11af55/width=450/1046170.jpeg" to /content/stable-diffusion-webui/models/Lora/wuxia2.preview.png
#
# 52.4kB [00:00, 26.7MB/s]
# Civitai: Downloading: "https://image.civitai.com/xG1nkqKTMzGDvpLrqFT7WA/45c92f20-2160-4e4c-8e95-51325edd5013/width=450/940065.jpeg" to /content/stable-diffusion-webui/models/Lora/magic-fantasy-forest-v2.preview.png
#
# 18.2kB [00:00, 35.0MB/s]
# Civitai: Downloading: "https://image.civitai.com/xG1nkqKTMzGDvpLrqFT7WA/bb27a977-8a4a-4803-bf7b-e3b9f3c1a6fa/width=450/852744.jpeg" to /content/stable-diffusion-webui/models/Stable-diffusion/meinapastel_v5AnimeIllustration.preview.png
#
# 70.7kB [00:00, 37.8MB/s]
# Civitai: Downloading: "https://image.civitai.com/xG1nkqKTMzGDvpLrqFT7WA/a3b1cddf-be5e-4cdc-9218-fb210479ae46/width=450/1183940.jpeg" to /content/stable-diffusion-webui/models/Lora/meloncat.preview.png
#
# 48.2kB [00:00, 38.3MB/s]
# Civitai: Downloading: "https://image.civitai.com/xG1nkqKTMzGDvpLrqFT7WA/01cae876-c4db-499a-35f2-3b784ba96900/width=450/483814.jpeg" to /content/stable-diffusion-webui/models/Lora/660.preview.png
#
# 62.3kB [00:00, 109MB/s]
# Civitai: Downloading: "https://image.civitai.com/xG1nkqKTMzGDvpLrqFT7WA/d7d60997-15a3-4ca5-bda3-af374617cbc4/width=450/1067258.jpeg" to /content/stable-diffusion-webui/models/Lora/Edob69MustangBoss_v1.0.preview.png
#
# 8.19MB [00:00, 47.3MB/s]
# Civitai: Downloading: "https://image.civitai.com/xG1nkqKTMzGDvpLrqFT7WA/59c42bbc-7c85-4726-ae6b-993910dfba0a/width=450/1153935.jpeg" to /content/stable-diffusion-webui/models/Lora/3DMM_V11.preview.png
#
# 40.3kB [00:00, 121MB/s]
# Civitai: Downloading: "https://image.civitai.com/xG1nkqKTMzGDvpLrqFT7WA/fb47849e-53e3-4076-895b-c486fea75017/width=450/945027.jpeg" to /content/stable-diffusion-webui/models/Lora/entropy-alpha.preview.png
#
# 40.3kB [00:00, 93.5MB/s]
# Civitai: Downloading: "https://image.civitai.com/xG1nkqKTMzGDvpLrqFT7WA/c1af593a-05c7-4847-9e8f-1b5f0c703494/width=450/1143511.jpeg" to /content/stable-diffusion-webui/embeddings/GS-DeMasculate-neg.preview.png
#
# 82.8kB [00:00, 42.1MB/s]
# Civitai: Downloading: "https://image.civitai.com/xG1nkqKTMzGDvpLrqFT7WA/966617fd-89bc-4909-b51b-c4558af5aaf7/width=450/1113092.jpeg" to /content/stable-diffusion-webui/embeddings/FastNegativeV2.preview.png
#
# 424kB [00:00, 93.9MB/s]
# Civitai: Downloading: "https://image.civitai.com/xG1nkqKTMzGDvpLrqFT7WA/ae9db089-5eda-4398-b048-ac24fab1f60d/width=450/1190520.jpeg" to /content/stable-diffusion-webui/models/LyCORIS/Midget2_v10.preview.png
#
# 36.0kB [00:00, 92.7MB/s]
# Civitai: Downloading: "https://image.civitai.com/xG1nkqKTMzGDvpLrqFT7WA/2fb0c01c-76ab-421e-9779-f0a9a27cc22a/width=450/1292738.jpeg" to /content/stable-diffusion-webui/models/Lora/Bubble Gum.preview.png
#
# 35.6kB [00:00, 74.3MB/s]
# Civitai: Downloading: "https://image.civitai.com/xG1nkqKTMzGDvpLrqFT7WA/949a8444-67d1-4a93-ba34-61b1675c164d/width=450/1216756.jpeg" to /content/stable-diffusion-webui/models/Lora/mangguo_keji.preview.png
#
# 55.4kB [00:00, 99.6MB/s]
# Civitai: Downloading: "https://image.civitai.com/xG1nkqKTMzGDvpLrqFT7WA/8ecd09f6-9c9d-49ac-8b7a-f0b96bce1b78/width=450/1131753.jpeg" to /content/stable-diffusion-webui/models/Stable-diffusion/CheckpointYesmix_v20.preview.png
#
# 185kB [00:00, 23.4MB/s]
# Civitai: Downloading: "https://image.civitai.com/xG1nkqKTMzGDvpLrqFT7WA/ab0ec541-a74b-4269-8ee8-c6cee147bca7/width=450/743009.jpeg" to /content/stable-diffusion-webui/models/LyCORIS/BikerC.preview.png
#
# 43.4kB [00:00, 41.8MB/s]
# Civitai: Downloading: "https://image.civitai.com/xG1nkqKTMzGDvpLrqFT7WA/2bc315ad-589e-479f-b4d4-037f9282db99/width=450/1179480.jpeg" to /content/stable-diffusion-webui/models/Lora/Lynx.preview.png
#
# 32.6kB [00:00, 82.4MB/s]
# Civitai: Downloading: "https://image.civitai.com/xG1nkqKTMzGDvpLrqFT7WA/095530a1-a1a5-4d7d-81db-db21eb7c46e6/width=450/1166727.jpeg" to /content/stable-diffusion-webui/models/Lora/TUSUN.preview.png
#
# 43.8kB [00:00, 94.7MB/s]
# Civitai: Downloading: "https://image.civitai.com/xG1nkqKTMzGDvpLrqFT7WA/739dc61f-ed2d-4da1-91fd-6ef9cb50f5f8/width=450/943826.jpeg" to /content/stable-diffusion-webui/models/Lora/gmushi.preview.png
#
# 34.1kB [00:00, 73.7MB/s]
# Civitai: Downloading: "https://image.civitai.com/xG1nkqKTMzGDvpLrqFT7WA/51b16903-34f7-45e9-a5fb-fd119badb186/width=450/1256672.jpeg" to /content/stable-diffusion-webui/models/Stable-diffusion/xxmix9realistic_v40.preview.png
#
# 34.7kB [00:00, 91.4MB/s]
# Civitai: Downloading: "https://image.civitai.com/xG1nkqKTMzGDvpLrqFT7WA/0511913f-bdd0-486b-943f-eaf0cacd24cf/width=450/950905.jpeg" to /content/stable-diffusion-webui/models/Lora/American style bedroom.preview.png
#
# 31.8kB [00:00, 74.7MB/s]
# Civitai: Downloading: "https://image.civitai.com/xG1nkqKTMzGDvpLrqFT7WA/8a9dc62e-404f-4984-af5a-40d297d1a29f/width=450/1015398.jpeg" to /content/stable-diffusion-webui/models/LyCORIS/daihatsu_midget_v11.preview.png
#
# 28.3kB [00:00, 57.7MB/s]
# Civitai: Downloading: "https://image.civitai.com/xG1nkqKTMzGDvpLrqFT7WA/c1697174-7c8d-4bde-b053-7b1ec0692b64/width=450/995787.jpeg" to /content/stable-diffusion-webui/models/Lora/more_details.preview.png
#
# 496kB [00:00, 41.0MB/s]
# Civitai: Downloading: "https://image.civitai.com/xG1nkqKTMzGDvpLrqFT7WA/94b4c731-0d53-4f64-8490-f052d2e8d76f/width=450/1192608.jpeg" to /content/stable-diffusion-webui/models/Lora/Caracal.preview.png
#
# 38.1kB [00:00, 59.4MB/s]
# Civitai: Downloading: "https://image.civitai.com/xG1nkqKTMzGDvpLrqFT7WA/83141d0c-ca55-4842-9e56-37fcfc327bac/width=450/1246585.jpeg" to /content/stable-diffusion-webui/models/Lora/arcibaldocat.preview.png
#
# 40.3kB [00:00, 90.7MB/s]
# Civitai: Updated 39 preview images
# Loading weights [b776728f83] from /content/stable-diffusion-webui/models/Stable-diffusion/CheckpointYesmix_v20.safetensors
# Loading VAE weights from commandline argument: cached vae-ft-mse-840000-ema-pruned.safetensors
# Applying xformers cross attention optimization.
# Weights loaded in 9.5s (load weights from disk: 1.0s, apply weights to model: 7.7s, load VAE: 0.1s, move model to device: 0.5s).
# Loading weights [6a27c56787] from /content/stable-diffusion-webui/models/Stable-diffusion/rcnzsDumbMonkey_v10.safetensors
# Loading VAE weights from commandline argument: cached vae-ft-mse-840000-ema-pruned.safetensors
# Applying xformers cross attention optimization.
# Weights loaded in 14.9s (load weights from disk: 1.3s, apply weights to model: 12.8s, load VAE: 0.2s, move model to device: 0.5s).
# Error running process: /content/stable-diffusion-webui/extensions/sd-dynamic-prompts/scripts/dynamic_prompting.py
# Traceback (most recent call last):
#   File "/content/stable-diffusion-webui/modules/scripts.py", line 417, in process
#     script.process(p, *script_args)
#   File "/content/stable-diffusion-webui/extensions/sd-dynamic-prompts/sd_dynamic_prompts/dynamic_prompting.py", line 478, in process
#     all_prompts, all_negative_prompts = generate_prompts(
#   File "/content/stable-diffusion-webui/extensions/sd-dynamic-prompts/sd_dynamic_prompts/helpers.py", line 93, in generate_prompts
#     all_prompts = prompt_generator.generate(prompt, num_prompts, seeds=seeds) or [""]
#   File "/usr/local/lib/python3.10/dist-packages/dynamicprompts/generators/randomprompt.py", line 71, in generate
#     prompts.append(next(iter(gen)))
# StopIteration
#
#   0% 0/20 [00:00<?, ?it/s]
#   5% 1/20 [00:02<00:45,  2.37s/it]
#  15% 3/20 [00:02<00:10,  1.58it/s]
#  25% 5/20 [00:02<00:04,  3.05it/s]
#  30% 6/20 [00:03<00:03,  3.82it/s]
#  35% 7/20 [00:03<00:02,  4.53it/s]
#  40% 8/20 [00:03<00:02,  5.07it/s]
#  45% 9/20 [00:03<00:01,  5.61it/s]
#  50% 10/20 [00:03<00:01,  6.03it/s]
#  55% 11/20 [00:03<00:01,  6.41it/s]
#  60% 12/20 [00:03<00:01,  6.69it/s]
#  65% 13/20 [00:04<00:01,  6.86it/s]
#  70% 14/20 [00:04<00:00,  7.00it/s]
#  75% 15/20 [00:04<00:00,  7.03it/s]
#  80% 16/20 [00:04<00:00,  7.07it/s]
#  85% 17/20 [00:04<00:00,  7.12it/s]
#  90% 18/20 [00:04<00:00,  7.18it/s]
#  95% 19/20 [00:04<00:00,  7.23it/s]
# 100% 20/20 [00:04<00:00,  4.02it/s]
#
# Total progress: 100% 20/20 [00:04<00:00,  4.55it/s]
#   0% 0/20 [00:00<?, ?it/s]
#   5% 1/20 [00:00<00:03,  5.00it/s]
#  15% 3/20 [00:00<00:02,  6.74it/s]
#  25% 5/20 [00:00<00:02,  7.17it/s]
#  30% 6/20 [00:00<00:01,  7.25it/s]
#  35% 7/20 [00:01<00:01,  7.29it/s]
#  40% 8/20 [00:01<00:01,  7.26it/s]
#  45% 9/20 [00:01<00:01,  7.28it/s]
#  50% 10/20 [00:01<00:01,  7.33it/s]
#  55% 11/20 [00:01<00:01,  7.34it/s]
#  60% 12/20 [00:01<00:01,  7.35it/s]
#  65% 13/20 [00:01<00:00,  7.38it/s]
#  70% 14/20 [00:01<00:00,  7.40it/s]
#  75% 15/20 [00:02<00:00,  7.36it/s]
#  80% 16/20 [00:02<00:00,  7.37it/s]
#  85% 17/20 [00:02<00:00,  7.36it/s]
#  90% 18/20 [00:02<00:00,  7.34it/s]
#  95% 19/20 [00:02<00:00,  7.35it/s]
# 100% 20/20 [00:02<00:00,  7.21it/s]
#
# Total progress: 100% 20/20 [00:02<00:00,  6.91it/s]
#   0% 0/20 [00:00<?, ?it/s]
#   5% 1/20 [00:00<00:03,  5.02it/s]
#  15% 3/20 [00:00<00:02,  6.40it/s]
#  20% 4/20 [00:00<00:02,  6.77it/s]
#  25% 5/20 [00:00<00:02,  6.99it/s]
#  30% 6/20 [00:00<00:01,  7.11it/s]
#  35% 7/20 [00:01<00:01,  7.20it/s]
#  40% 8/20 [00:01<00:01,  7.26it/s]
#  45% 9/20 [00:01<00:01,  7.28it/s]
#  50% 10/20 [00:01<00:01,  7.33it/s]
#  55% 11/20 [00:01<00:01,  7.37it/s]
#  60% 12/20 [00:01<00:01,  7.38it/s]
#  65% 13/20 [00:01<00:00,  7.39it/s]
#  70% 14/20 [00:01<00:00,  7.39it/s]
#  75% 15/20 [00:02<00:00,  7.40it/s]
#  80% 16/20 [00:02<00:00,  7.39it/s]
#  85% 17/20 [00:02<00:00,  7.41it/s]
#  90% 18/20 [00:02<00:00,  7.38it/s]
#  95% 19/20 [00:02<00:00,  7.35it/s]
# 100% 20/20 [00:02<00:00,  7.16it/s]
#
# Total progress: 100% 20/20 [00:02<00:00,  6.86it/s]
#   0% 0/20 [00:00<?, ?it/s]
#   5% 1/20 [00:00<00:03,  5.17it/s]
#  15% 3/20 [00:00<00:02,  6.77it/s]
#  25% 5/20 [00:00<00:02,  7.14it/s]
#  30% 6/20 [00:00<00:01,  7.21it/s]
#  35% 7/20 [00:01<00:01,  7.21it/s]
#  40% 8/20 [00:01<00:01,  7.23it/s]
#  45% 9/20 [00:01<00:01,  7.27it/s]
#  50% 10/20 [00:01<00:01,  7.28it/s]
#  55% 11/20 [00:01<00:01,  7.26it/s]
#  60% 12/20 [00:01<00:01,  7.21it/s]
#  65% 13/20 [00:01<00:00,  7.26it/s]
#  70% 14/20 [00:01<00:00,  7.24it/s]
#  75% 15/20 [00:02<00:00,  7.24it/s]
#  80% 16/20 [00:02<00:00,  7.25it/s]
#  85% 17/20 [00:02<00:00,  7.26it/s]
#  90% 18/20 [00:02<00:00,  7.28it/s]
#  95% 19/20 [00:02<00:00,  7.31it/s]
# 100% 20/20 [00:02<00:00,  7.16it/s]
#
# Total progress: 100% 20/20 [00:02<00:00,  6.87it/s]
# Interrupted with signal 2 in <frame at 0x2d483990, file '/content/stable-diffusion-webui/webui.py', line 209, code wait_on_server>

# %% [markdown]
# # Last update
#
# - Added models: AniFlatMixAnimeFlatColorStyle 1.0, Animatrix v2, Bra v4, Cardos Anime v2, Colorful v3, Divine Elegance Mix v5, DucHaiten AI Art v4.5.3, DucHaiten GodOfSimp v0.2, Eimis Anime Model 2.0, Feelyou Alpha 1, Flat 2D Animerge v1, Hassaku Hentai Model v1.1, Hassan Blend 1.5.1.2, Lyriel v1.5, Mix Pro v4, Needyou Alpha 2, Toonyou Alpha 3, Xrikishi's Unstable Alpha 6
# - Made vae-ft-mse-840000 default vae, loaded at startup. However, the vae selector still shows "Automatic" on startup
#
# # Thanks
# - Camenduru
# > For his awesome github repositories and simple colabs that made me want to start this.
# - Etherealxx
# > For his help, his Batchlink Downloader and being patient with me when I was stupid :p
# - imi
# > Probably my best supporter as of now. Good feedback, suggestions, and for being generally aventurous in the generative ai world. I like to see people being curious :p
#
# Bytes on you guys 👍
#
# # Bugs, praises, and insults
# [Discord](https://discord.com/channels/1077510466470952990/1079216601829740666) --- [Github](https://shorturl.at/anFW8)
#
# # ToDo List
#
# - Fix vae selector to reflect default vae
# - Update vae comparison grids
#
# # Planned features
#
# - Add inpaint version for models that have one (with yes/no choice)
# - Google Drive support
# - Colab Timer (will shamelessly steal it from NoCrypt's colab, probably along a few others QoL :p Sorry NoCrypt, bytes on you!)
# - Webui selector (current and Vladmantic)
# - Another project (discord knows...)
